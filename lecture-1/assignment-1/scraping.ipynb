# %% [markdown]
# ## 個人課題１
# - Github上でGoogleが管理しているリポジトリの情報をスクレイピングして下記の情報を取得する
#     - リポジトリ名
#     - 主要な言語
#     - スターの数
# - 上記のデータを保存するためのDBを作成し，スクレイピングしたデータを保存する
#     - GithubのAPIは使わないこと（スクレイピングの課題なので）
#     - ちゃんと`time.sleep(1)`入れてね
# - 保存したデータをSELECT文で表示する

# %%
import sqlite3
import requests
from bs4 import BeautifulSoup
import time

# %%
# 取得したリポジトリを保存するデータベースのテーブルを作成
path = ''
db_name = 'repositories.db'

try:
    # DB接続オブジェクトの作成
    conn = sqlite3.connect(path + db_name)

    # SQL(RUBを操作するための言語)を実行するためのカーソルオブジェクトを取得
    cur = conn.cursor()

    # SQL文の作成
    # テーブルの作成
    sql = 'CREATE TABLE repositories(id INTEGER PRIMARY KEY, name TEXT, language TEXT, stars REAL);'

    # SQL文の実行
    cur.execute(sql)

except sqlite3.Error as e:
    print('エラーが発生しました：', e)

finally:
    # DBへの接続を閉じる
    conn.close()

# %%
path = ''
db_name = 'repositories.db'

total = 0

# aタグの中のaria-labelにstarsが含まれている場合にTrueを返す関数
def has_stars(tag):
    # a タグでなければスキップ
    if tag.name != "a":
        return False
    aria = tag.get("aria-label")
    return aria is not None and "stars" in aria

# 全てのリポジトリを取得するために全てのページにアクセスする
for page in range(1, 95):
    time.sleep(1)
    url = f"https://github.com/orgs/google/repositories?page={page}"
    response = requests.get(url)
    # ステータスコードが200以外の場合に例外を発生させる
    response.raise_for_status()
    print("ステータスコード:", response.status_code)
    print("-----")
    response.encoding = response.apparent_encoding 
    soup = BeautifulSoup(response.text, "html.parser")

    # リポジトリのブロックを取得するコードをかく
    # 各リポジトリが一つの<li>タグとしてまとまっているのでそれを取得
    repo_blocks = soup.find_all('li', class_="ListItem-module__listItem--k4eMk")
    for repo_block in repo_blocks:
        time.sleep(1)

        # リポジトリの名前を取得
        # aタグの中の指定したクラスの中にあるテキストを取得する
        a_tag = repo_block.find('a', class_="Title-module__anchor--GmXUE Title-module__inline--oM0P7")
        if a_tag:
            repo_name = a_tag.get_text()
        else:
            repo_name = None
        # print(repo_name)

        # 主要な言語の取得
        # spanタグの中の指定したクラスの中にあるテキストを取得する
        language_tags = repo_block.find('span', class_='ReposListItem-module__Text_4--mkG7R')
        if language_tags:
            language = language_tags.get_text()
        else:
            language = None
        # print(language)

        # スターの数の取得
        star_tags = repo_block.find(has_stars)
        if star_tags:
            stars_num = star_tags.get_text()  
        else:
            stars_num = None
        # print(stars_num)

        # 取得したリポジトリの名前と主要な言語とスターの数をデータベースに保存
        try:
            # DB接続オブジェクトの作成
            conn = sqlite3.connect(path + db_name)

            # SQL(RUBを操作するための言語)を実行するためのカーソルp武ジェクトを取得
            cur = conn.cursor()

            # データ挿入のSQL文
            sql = "INSERT INTO repositories (name, language, stars) VALUES (?, ?, ?);"

            repositories = [
                (repo_name, language, stars_num)
            ]

            cur.executemany(sql, repositories)

            # 変更をDBに反映させる
            conn.commit()
            
        except sqlite3.Error as e:
            print('エラーが発生しました：', e)

        finally:
            # DBへの接続を閉じる
            conn.close()
        
        total += 1
    # 途中経過の表示
    print(f"【ページ {page} 終了】 現在までの取得件数：{total} 件")
    print("-----")

print("==== 全ページ取得完了 ====")
print(f"総件数：{total} 件")
# Out:
# ステータスコード: 200
# -----
# 【ページ 1 終了】 現在までの取得件数：30 件
# -----
# ステータスコード: 200
# -----
# 【ページ 2 終了】 現在までの取得件数：60 件
# -----
# ステータスコード: 200
# -----
# 【ページ 3 終了】 現在までの取得件数：90 件
# -----
# ステータスコード: 200
# -----
# 【ページ 4 終了】 現在までの取得件数：120 件
# -----
# ステータスコード: 200
# -----
# 【ページ 5 終了】 現在までの取得件数：150 件
# -----
# ステータスコード: 200
# -----
# 【ページ 6 終了】 現在までの取得件数：180 件
# -----
# ステータスコード: 200
# -----
# 【ページ 7 終了】 現在までの取得件数：210 件
# -----
# ステータスコード: 200
# -----
# 【ページ 8 終了】 現在までの取得件数：240 件
# -----
# ステータスコード: 200
# -----
# 【ページ 9 終了】 現在までの取得件数：270 件
# -----
# ステータスコード: 200
# -----
# 【ページ 10 終了】 現在までの取得件数：300 件
# -----
# ステータスコード: 200
# -----
# 【ページ 11 終了】 現在までの取得件数：330 件
# -----
# ステータスコード: 200
# -----
# 【ページ 12 終了】 現在までの取得件数：360 件
# -----
# ステータスコード: 200
# -----
# 【ページ 13 終了】 現在までの取得件数：390 件
# -----
# ステータスコード: 200
# -----
# 【ページ 14 終了】 現在までの取得件数：420 件
# -----
# ステータスコード: 200
# -----
# 【ページ 15 終了】 現在までの取得件数：450 件
# -----
# ステータスコード: 200
# -----
# 【ページ 16 終了】 現在までの取得件数：480 件
# -----
# ステータスコード: 200
# -----
# 【ページ 17 終了】 現在までの取得件数：510 件
# -----
# ステータスコード: 200
# -----
# 【ページ 18 終了】 現在までの取得件数：540 件
# -----
# ステータスコード: 200
# -----
# 【ページ 19 終了】 現在までの取得件数：570 件
# -----
# ステータスコード: 200
# -----
# 【ページ 20 終了】 現在までの取得件数：600 件
# -----
# ステータスコード: 200
# -----
# 【ページ 21 終了】 現在までの取得件数：630 件
# -----
# ステータスコード: 200
# -----
# 【ページ 22 終了】 現在までの取得件数：660 件
# -----
# ステータスコード: 200
# -----
# 【ページ 23 終了】 現在までの取得件数：690 件
# -----
# ステータスコード: 200
# -----
# 【ページ 24 終了】 現在までの取得件数：720 件
# -----
# ステータスコード: 200
# -----
# 【ページ 25 終了】 現在までの取得件数：750 件
# -----
# ステータスコード: 200
# -----
# 【ページ 26 終了】 現在までの取得件数：780 件
# -----
# ステータスコード: 200
# -----
# 【ページ 27 終了】 現在までの取得件数：810 件
# -----
# ステータスコード: 200
# -----
# 【ページ 28 終了】 現在までの取得件数：840 件
# -----
# ステータスコード: 200
# -----
# 【ページ 29 終了】 現在までの取得件数：870 件
# -----
# ステータスコード: 200
# -----
# 【ページ 30 終了】 現在までの取得件数：900 件
# -----
# ステータスコード: 200
# -----
# 【ページ 31 終了】 現在までの取得件数：930 件
# -----
# ステータスコード: 200
# -----
# 【ページ 32 終了】 現在までの取得件数：960 件
# -----
# ステータスコード: 200
# -----
# 【ページ 33 終了】 現在までの取得件数：990 件
# -----
# ステータスコード: 200
# -----
# 【ページ 34 終了】 現在までの取得件数：1020 件
# -----
# ステータスコード: 200
# -----
# 【ページ 35 終了】 現在までの取得件数：1050 件
# -----
# ステータスコード: 200
# -----
# 【ページ 36 終了】 現在までの取得件数：1080 件
# -----
# ステータスコード: 200
# -----
# 【ページ 37 終了】 現在までの取得件数：1110 件
# -----
# ステータスコード: 200
# -----
# 【ページ 38 終了】 現在までの取得件数：1140 件
# -----
# ステータスコード: 200
# -----
# 【ページ 39 終了】 現在までの取得件数：1170 件
# -----
# ステータスコード: 200
# -----
# 【ページ 40 終了】 現在までの取得件数：1200 件
# -----
# ステータスコード: 200
# -----
# 【ページ 41 終了】 現在までの取得件数：1230 件
# -----
# ステータスコード: 200
# -----
# 【ページ 42 終了】 現在までの取得件数：1260 件
# -----
# ステータスコード: 200
# -----
# 【ページ 43 終了】 現在までの取得件数：1290 件
# -----
# ステータスコード: 200
# -----
# 【ページ 44 終了】 現在までの取得件数：1320 件
# -----
# ステータスコード: 200
# -----
# 【ページ 45 終了】 現在までの取得件数：1350 件
# -----
# ステータスコード: 200
# -----
# 【ページ 46 終了】 現在までの取得件数：1380 件
# -----
# ステータスコード: 200
# -----
# 【ページ 47 終了】 現在までの取得件数：1410 件
# -----
# ステータスコード: 200
# -----
# 【ページ 48 終了】 現在までの取得件数：1440 件
# -----
# ステータスコード: 200
# -----
# 【ページ 49 終了】 現在までの取得件数：1470 件
# -----
# ステータスコード: 200
# -----
# 【ページ 50 終了】 現在までの取得件数：1500 件
# -----
# ステータスコード: 200
# -----
# 【ページ 51 終了】 現在までの取得件数：1530 件
# -----
# ステータスコード: 200
# -----
# 【ページ 52 終了】 現在までの取得件数：1560 件
# -----
# ステータスコード: 200
# -----
# 【ページ 53 終了】 現在までの取得件数：1590 件
# -----
# ステータスコード: 200
# -----
# 【ページ 54 終了】 現在までの取得件数：1620 件
# -----
# ステータスコード: 200
# -----
# 【ページ 55 終了】 現在までの取得件数：1650 件
# -----
# ステータスコード: 200
# -----
# 【ページ 56 終了】 現在までの取得件数：1680 件
# -----
# ステータスコード: 200
# -----
# 【ページ 57 終了】 現在までの取得件数：1710 件
# -----
# ステータスコード: 200
# -----
# 【ページ 58 終了】 現在までの取得件数：1740 件
# -----
# ステータスコード: 200
# -----
# 【ページ 59 終了】 現在までの取得件数：1770 件
# -----
# ステータスコード: 200
# -----
# 【ページ 60 終了】 現在までの取得件数：1800 件
# -----
# ステータスコード: 200
# -----
# 【ページ 61 終了】 現在までの取得件数：1830 件
# -----
# ステータスコード: 200
# -----
# 【ページ 62 終了】 現在までの取得件数：1860 件
# -----
# ステータスコード: 200
# -----
# 【ページ 63 終了】 現在までの取得件数：1890 件
# -----
# ステータスコード: 200
# -----
# 【ページ 64 終了】 現在までの取得件数：1920 件
# -----
# ステータスコード: 200
# -----
# 【ページ 65 終了】 現在までの取得件数：1950 件
# -----
# ステータスコード: 200
# -----
# 【ページ 66 終了】 現在までの取得件数：1980 件
# -----
# ステータスコード: 200
# -----
# 【ページ 67 終了】 現在までの取得件数：2010 件
# -----
# ステータスコード: 200
# -----
# 【ページ 68 終了】 現在までの取得件数：2040 件
# -----
# ステータスコード: 200
# -----
# 【ページ 69 終了】 現在までの取得件数：2070 件
# -----
# ステータスコード: 200
# -----
# 【ページ 70 終了】 現在までの取得件数：2100 件
# -----
# ステータスコード: 200
# -----
# 【ページ 71 終了】 現在までの取得件数：2130 件
# -----
# ステータスコード: 200
# -----
# 【ページ 72 終了】 現在までの取得件数：2160 件
# -----
# ステータスコード: 200
# -----
# 【ページ 73 終了】 現在までの取得件数：2190 件
# -----
# ステータスコード: 200
# -----
# 【ページ 74 終了】 現在までの取得件数：2220 件
# -----
# ステータスコード: 200
# -----
# 【ページ 75 終了】 現在までの取得件数：2250 件
# -----
# ステータスコード: 200
# -----
# 【ページ 76 終了】 現在までの取得件数：2280 件
# -----
# ステータスコード: 200
# -----
# 【ページ 77 終了】 現在までの取得件数：2310 件
# -----
# ステータスコード: 200
# -----
# 【ページ 78 終了】 現在までの取得件数：2340 件
# -----
# ステータスコード: 200
# -----
# 【ページ 79 終了】 現在までの取得件数：2370 件
# -----
# ステータスコード: 200
# -----
# 【ページ 80 終了】 現在までの取得件数：2400 件
# -----
# ステータスコード: 200
# -----
# 【ページ 81 終了】 現在までの取得件数：2430 件
# -----
# ステータスコード: 200
# -----
# 【ページ 82 終了】 現在までの取得件数：2460 件
# -----
# ステータスコード: 200
# -----
# 【ページ 83 終了】 現在までの取得件数：2490 件
# -----
# ステータスコード: 200
# -----
# 【ページ 84 終了】 現在までの取得件数：2520 件
# -----
# ステータスコード: 200
# -----
# 【ページ 85 終了】 現在までの取得件数：2550 件
# -----
# ステータスコード: 200
# -----
# 【ページ 86 終了】 現在までの取得件数：2580 件
# -----
# ステータスコード: 200
# -----
# 【ページ 87 終了】 現在までの取得件数：2610 件
# -----
# ステータスコード: 200
# -----
# 【ページ 88 終了】 現在までの取得件数：2640 件
# -----
# ステータスコード: 200
# -----
# 【ページ 89 終了】 現在までの取得件数：2670 件
# -----
# ステータスコード: 200
# -----
# 【ページ 90 終了】 現在までの取得件数：2700 件
# -----
# ステータスコード: 200
# -----
# 【ページ 91 終了】 現在までの取得件数：2730 件
# -----
# ステータスコード: 200
# -----
# 【ページ 92 終了】 現在までの取得件数：2760 件
# -----
# ステータスコード: 200
# -----
# 【ページ 93 終了】 現在までの取得件数：2790 件
# -----
# ステータスコード: 200
# -----
# 【ページ 94 終了】 現在までの取得件数：2811 件
# -----
# ==== 全ページ取得完了 ====
# 総件数：2811 件

# %%
# データベースに保存したデータをSELECT文を用いて表示
path = ''
db_name = 'repositories.db'

try:
    # DB接続オブジェクトの作成
    conn = sqlite3.connect(path + db_name)

    # SQL(RUBを操作するための言語)を実行するためのカーソルp武ジェクトを取得
    cur = conn.cursor()

    # SQL文の作成
    # SELECT * FROM テーブル名;
    # *　の部分は取得したい列の名前を区切りで指定することができる
    sql = "SELECT * FROM repositories;"

    # SQL文の実行
    cur.execute(sql)
    
except sqlite3.Error as e:
    print('エラーが発生しました：', e)

else:
    for row in cur:
        # 行データ(row)はタプルなので、アンバックして列データを取得
        id, name, language, stars = row
        print(row)

finally:
    # DBへの接続を閉じる
    conn.close()
# Out:
# (1, 'tunix', 'Python', '1.9k')
# (2, 'device-infra', 'Java', 58.0)
# (3, 'dive', 'C++', 17.0)
# (4, 'nomulus', 'Java', '1.8k')
# (5, 'jetpack-camera-app', 'Kotlin', 275.0)
# (6, 'gvisor', 'Go', '17k')
# (7, 'quiche', 'C++', 801.0)
# (8, 'cel-java', 'Java', 227.0)
# (9, 'dawn', 'C++', 770.0)
# (10, 'XNNPACK', 'C', '2.2k')
# (11, 'j2cl', 'Java', '1.3k')
# (12, 'xls', 'C++', '1.4k')
# (13, 'orbax', 'Python', 454.0)
# (14, 'ml-metrics', 'Python', 18.0)
# (15, 'perfetto', 'C++', '5k')
# (16, 'automotive-design-compose', 'Rust', 164.0)
# (17, 'TestParameterInjector', 'Java', 415.0)
# (18, 'adk-python', 'Python', '15k')
# (19, 'grain', 'Python', 601.0)
# (20, 'meridian', 'Python', '1.2k')
# (21, 'docsy', 'JavaScript', '2.9k')
# (22, 'heir', 'C++', 605.0)
# (23, 'init2winit', 'Python', 79.0)
# (24, 'langfun', 'Python', 875.0)
# (25, 'filament', 'C++', '19k')
# (26, 'chromium-policy-vulnfeed', 'Go', 7.0)
# (27, 'bloaty', 'C++', '5.3k')
# (28, 's2geometry', 'C++', '2.6k')
# (29, 'pullsheet', 'Go', 88.0)
# (30, 'nearby', 'C++', 881.0)
# (31, 'nsscache', 'Python', 150.0)
# (32, 'adk-samples', 'Python', '6.4k')
# (33, 'crubit', 'C++', 924.0)
# (34, 'zerocopy', 'Rust', '2.1k')
# (35, 'Xee', 'Python', 320.0)
# (36, 'ecclesia-machine-management', 'C++', 15.0)
# (37, 'adk-docs', 'HTML', 969.0)
# (38, 'embardiment', 'C#', 4.0)
# (39, 'koladata', 'C++', 27.0)
# (40, 'earthengine-community', 'Jupyter Notebook', 743.0)
# (41, 'tcmalloc', 'C++', '5k')
# (42, 'osv-scalibr', 'Go', 532.0)
# (43, 'aqt', 'Python', 337.0)
# (44, 'ground-android', 'Kotlin', 272.0)
# (45, 'adk-java', 'Java', 945.0)
# (46, 'angle', 'C++', '3.8k')
# (47, 'yggdrasil-decision-forests', 'C++', 620.0)
# (48, 'skia', 'C++', '10k')
# (49, 'skia-buildbot', 'Go', 157.0)
# (50, 'error-prone', 'Java', '7.1k')
# (51, 'torchax', 'Python', 126.0)
# (52, 'pdl', 'Rust', 66.0)
# (53, 'mcp-security', 'Python', 404.0)
# (54, 'oss-rebuild', 'Go', 668.0)
# (55, 'atheris', 'Python', '1.5k')
# (56, 'fonts', 'HTML', '19k')
# (57, 'adk-python-community', 'Python', 91.0)
# (58, 'json_serializable.dart', 'Dart', '1.6k')
# (59, 'xrblocks', 'TypeScript', 154.0)
# (60, 'ksp', 'Kotlin', '3.3k')
# (61, 'fuzztest', 'C++', 920.0)
# (62, 'android-cuttlefish', 'C++', 570.0)
# (63, 'benchmark', 'C++', '9.8k')
# (64, 'gson', 'Java', '24k')
# (65, 'qwix', 'Python', 61.0)
# (66, 'jsonschema-go', 'Go', 136.0)
# (67, 'gops', 'Go', '7k')
# (68, 'adk-js', 'TypeScript', 91.0)
# (69, 'cel-cpp', 'C++', 205.0)
# (70, 'tarpc', 'Rust', '3.6k')
# (71, 'civics_cdf_validator', 'Python', 34.0)
# (72, 'osv-scanner', 'Go', '8.1k')
# (73, 'dagger', 'Java', '18k')
# (74, 'osv.dev', 'Python', '2.4k')
# (75, 'oracle-toolkit', 'Shell', 65.0)
# (76, 'dranet', 'Go', 146.0)
# (77, 'site-kit-wp', 'JavaScript', '1.3k')
# (78, 'earthengine-api', 'JavaScript', '3.1k')
# (79, 'go-attestation', 'Go', 404.0)
# (80, 'filonov', 'Python', 10.0)
# (81, 'libnss-cache', 'C', 61.0)
# (82, 'assertor', 'Rust', 144.0)
# (83, 'ground-platform', 'TypeScript', 226.0)
# (84, 'closure-templates', 'Java', 671.0)
# (85, 'flax', 'Jupyter Notebook', '6.9k')
# (86, 'adk-go', 'Go', '4.3k')
# (87, 'clspv', 'LLVM', 692.0)
# (88, 'gemma.cpp', 'C++', '6.6k')
# (89, 'langextract', 'Python', '17k')
# (90, 'secure-aggregation', 'Rust', 5.0)
# (91, 'pack', 'Rust', 202.0)
# (92, 'gurl', 'C++', 0.0)
# (93, 'shell-encryption', 'C++', 124.0)
# (94, 'certificate-transparency-go', 'Go', '1.1k')
# (95, 'source_helper.dart', 'Dart', 16.0)
# (96, 'mug', 'Java', 443.0)
# (97, 'conscrypt', 'Java', '1.4k')
# (98, 'libphonenumber', 'C++', '18k')
# (99, 'copybara', 'Java', '2.5k')
# (100, 'earthengine-catalog', 'Jsonnet', 121.0)
# (101, 'oss-fuzz-vulns', 'Python', 166.0)
# (102, 'sentencepiece', 'C++', '11k')
# (103, 'dart-neats', 'Dart', 503.0)
# (104, 'go-querystring', 'Go', '2.1k')
# (105, 'timesketch', 'Python', '3.2k')
# (106, 'snappy', 'C++', '6.5k')
# (107, 'trillian-examples', 'Go', 173.0)
# (108, 'oss-fuzz', 'Shell', '12k')
# (109, 'android-security-lints', 'Kotlin', 153.0)
# (110, 'secops-wrapper', 'Python', 44.0)
# (111, 'syzkaller', 'Go', '5.9k')
# (112, 'dwh-migration-tools', 'Java', 54.0)
# (113, 'workflow-graph', 'TypeScript', 149.0)
# (114, 'android-fhir', 'Kotlin', 568.0)
# (115, 'silifuzz', 'C++', 412.0)
# (116, 'highway', 'C++', '5.1k')
# (117, 'mozc', 'C++', '2.8k')
# (118, 'garf', 'Python', 10.0)
# (119, 'tensorstore', 'C++', '1.5k')
# (120, 'peoplemath', 'TypeScript', 128.0)
# (121, 'brotli', 'TypeScript', '14k')
# (122, 'kotlin-fhirpath', 'Kotlin', 6.0)
# (123, 'digitalbuildings', 'Python', 424.0)
# (124, 'fscrypt', 'Go', 983.0)
# (125, 'go-units', 'Go', 7.0)
# (126, 'trillian', 'Go', '3.7k')
# (127, 'go-github', 'Go', '11k')
# (128, 'gke-policy-automation', 'Go', 525.0)
# (129, 'merchant-api-samples', 'Java', 10.0)
# (130, 'go-cloud', 'Go', '9.8k')
# (131, 'aoss-verifier', 'Go', 25.0)
# (132, 'go-containerregistry', 'Go', '3.6k')
# (133, 'seesaw', 'Go', '5.7k')
# (134, 'go-jsonnet', 'Go', '1.8k')
# (135, 'osv-scanner-v1', 'Go', 2.0)
# (136, 'security-research', 'C', '4.3k')
# (137, 'certtostore', 'Go', 96.0)
# (138, 'neuroglancer', 'TypeScript', '1.2k')
# (139, 'crosvm', 'Rust', '1.1k')
# (140, 'minijail', 'C', 341.0)
# (141, 'netkat', 'C++', 27.0)
# (142, 'osv-scanner-action', 'Python', 47.0)
# (143, 'jax-datetime', 'Python', 2.0)
# (144, 'glome', 'C', 63.0)
# (145, 'gutil', 'C++', 11.0)
# (146, 'boringssl', 'C++', '2.1k')
# (147, 'fleetbench', 'C++', 134.0)
# (148, 'testrun', 'Python', 42.0)
# (149, 'across', 'HTML', 21.0)
# (150, 'budoux-extension', 'TypeScript', 16.0)
# (151, 'closure-compiler', 'JavaScript', '7.6k')
# (152, 'scaaml', 'Python', 175.0)
# (153, 'ink', 'C++', 49.0)
# (154, 'fhir', 'C++', 904.0)
# (155, 'dotprompt', 'Python', 325.0)
# (156, 'clusterfuzz', 'Python', '5.5k')
# (157, 'horologist', 'Kotlin', 656.0)
# (158, 'nccl-plugin-gpudirect-tcpxo', 'C++', 6.0)
# (159, 'tsl', 'C++', 101.0)
# (160, 'llvm-propeller', 'C++', 463.0)
# (161, 'gnostic-models', 'Go', 20.0)
# (162, 'go-sev-guest', 'Go', 66.0)
# (163, 'fhir-gateway', 'Java', 90.0)
# (164, 'kotlin', 'Kotlin', 153.0)
# (165, 'or-tools', 'C++', '13k')
# (166, 'open-dice', 'C++', 26.0)
# (167, 'googletest-rust', 'Rust', 393.0)
# (168, 'android-beat', None, 2.0)
# (169, 'bumble', 'Python', 425.0)
# (170, 'gwpsan', 'C++', 329.0)
# (171, 'nftables', 'Go', '1.3k')
# (172, 'wasefire', 'Rust', 123.0)
# (173, 'clasp', 'TypeScript', '5.3k')
# (174, 'guava', 'Java', '51k')
# (175, 'go-tdx-guest', 'Go', 79.0)
# (176, 'googleapis.dart', 'Dart', 408.0)
# (177, 'openhtf', 'Python', 612.0)
# (178, 'github_workflows_playground', None, 8.0)
# (179, 'eclipsa-audio-plugin', 'C++', 55.0)
# (180, 'adk-web', 'TypeScript', 660.0)
# (181, 'gce-tcb-verifier', 'Go', 22.0)
# (182, 'github-team', 'Shell', 2.0)
# (183, 'pyglove', 'Python', 698.0)
# (184, 'shaderc', 'C++', '2.1k')
# (185, 'fhir-data-pipes', 'Jupyter Notebook', 203.0)
# (186, 'cel-go', 'Go', '2.8k')
# (187, 'arolla', 'C++', 23.0)
# (188, 'inverting-proxy', 'Go', 262.0)
# (189, 'ChromeBrowserEnterprise', 'C#', 57.0)
# (190, 'travel-impact-model-website', 'TypeScript', 5.0)
# (191, 'learned_optimization', 'Python', 788.0)
# (192, 'gfxstream', 'C++', 21.0)
# (193, 'rpmpack', 'Go', 127.0)
# (194, 'cctz', 'C++', 631.0)
# (195, 'weather-tools', 'Python', 240.0)
# (196, 'schema-dts', 'TypeScript', '1.1k')
# (197, 'foteli', 'C++', 5.0)
# (198, 'protobuf.dart', 'Dart', 557.0)
# (199, 'sedpack', 'Python', 28.0)
# (200, 'mdbook-i18n-helpers', 'Rust', 194.0)
# (201, 'zx', 'JavaScript', '45k')
# (202, 'tabuli', 'C++', 35.0)
# (203, 'deps.dev', 'Go', 354.0)
# (204, 'tsec', 'TypeScript', 141.0)
# (205, 'github-sandbox', None, 16.0)
# (206, 'dotguides', 'TypeScript', 21.0)
# (207, 'aarch64-esr-decoder', 'Rust', 99.0)
# (208, 'torq', 'Python', 2.0)
# (209, 'osdfir-infrastructure', 'Smarty', 171.0)
# (210, 'github_nonpublic_api', 'Python', 43.0)
# (211, 'cel-spec', 'Starlark', '3.5k')
# (212, 'libhoth', 'C', 17.0)
# (213, 'flatbuffers', 'C++', '25k')
# (214, 'oss-fuzz-gen', 'Python', '1.3k')
# (215, 'auto', 'Java', '11k')
# (216, 'xctestrunner', 'Python', 152.0)
# (217, 'escapevelocity', 'Java', 39.0)
# (218, 'postcss-rename', 'TypeScript', 161.0)
# (219, 'praxis', 'Python', 190.0)
# (220, 'transit', None, 851.0)
# (221, 'riegeli', 'C++', 465.0)
# (222, 'swiftshader', 'C++', '2.4k')
# (223, 'osdemo', 'Rust', 8.0)
# (224, 'j2objc', 'Java', '6k')
# (225, 'turbine', 'Java', 82.0)
# (226, 'differential-privacy', 'Go', '3.3k')
# (227, 'caliper', 'Java', 819.0)
# (228, 'aidl-language', None, 23.0)
# (229, 'selinux-policy-languages', None, 14.0)
# (230, 'pdl-language', None, 26.0)
# (231, 'comprehensive-rust', 'Rust', '32k')
# (232, 'webcrypto.dart', 'Dart', 97.0)
# (233, 'budoux', 'Python', '1.5k')
# (234, 'pytype', 'Python', '5k')
# (235, 'paxml', 'Python', 540.0)
# (236, 'renameio', 'Go', 666.0)
# (237, 'seqio', 'Python', 589.0)
# (238, 'google-toolbox-for-mac', 'Objective-C', '1.2k')
# (239, 'gtm-session-fetcher', 'Objective-C', 265.0)
# (240, 'alioth', 'Rust', 307.0)
# (241, 'iwa-vscode-extension', 'TypeScript', 2.0)
# (242, 'mobly', 'Python', 716.0)
# (243, 'project-voice', 'TypeScript', 49.0)
# (244, 'duet', 'Python', 24.0)
# (245, 'cro3', 'Rust', 49.0)
# (246, 'arb-editor', 'TypeScript', 56.0)
# (247, 'codeql-action', 'TypeScript', 0.0)
# (248, 'dfindexeddb', 'Python', 38.0)
# (249, 'sound-checker', 'Kotlin', 22.0)
# (250, 'traceviz', 'TypeScript', 4.0)
# (251, 'etils', 'Python', 244.0)
# (252, 'labs-prototypes', 'Jupyter Notebook', 85.0)
# (253, 'vector_math.dart', 'Dart', 334.0)
# (254, 'pprof', 'Go', '8.9k')
# (255, 'rust-crate-audits', None, 255.0)
# (256, 'aarch64-rt', 'Rust', 16.0)
# (257, 'aside', 'TypeScript', 392.0)
# (258, 'privacy-sandbox-aggregation-service', 'Go', 28.0)
# (259, 'rbrotli-enc', 'Rust', 13.0)
# (260, 'ads-api-report-fetcher', 'TypeScript', 53.0)
# (261, 'guice', 'Java', '13k')
# (262, 'mobly-bundled-snippets', 'Java', 54.0)
# (263, 'metrax', 'Python', 46.0)
# (264, 'magika', 'Python', '9.8k')
# (265, 'sec-gemini', 'Svelte', 105.0)
# (266, 'symphony-gcp', 'Python', None)
# (267, 'cameratrapai', 'Python', 385.0)
# (268, 'ml-compiler-opt', 'Python', 737.0)
# (269, 'google-cloud-datastore-quadruple', 'M4', 2.0)
# (270, 'styleguide', 'HTML', '39k')
# (271, 'array_record', 'C++', 121.0)
# (272, 'mobly-android-screen-recorder', 'Python', 5.0)
# (273, 'certificate-transparency-community-site', 'HTML', 132.0)
# (274, 'tsunami-security-scanner-plugins', 'Java', 942.0)
# (275, 'tsunami-security-scanner', 'Java', '8.5k')
# (276, 'keep-sorted', 'Go', 315.0)
# (277, 'docsy-example', 'HTML', 536.0)
# (278, 'perf_data_converter', 'C++', 331.0)
# (279, 'android-emulator-hypervisor-driver', 'C', 840.0)
# (280, 'ads_oneshop', 'Python', 19.0)
# (281, 'EarlGrey', 'Objective-C', '5.7k')
# (282, 'zetasql', 'C++', '2.4k')
# (283, 'myvibe', None, 3.0)
# (284, 'business_intelligence_group', 'Jupyter Notebook', 14.0)
# (285, 'mobly-bluetooth-ref-validation', 'Python', 5.0)
# (286, 'googletest', 'C++', '37k')
# (287, 'oboe', 'C++', '4k')
# (288, 'cloud-android-orchestration', 'Go', 58.0)
# (289, 'compile-testing', 'Java', 715.0)
# (290, 'fhir-py', 'Python', 94.0)
# (291, 'product_video_ads', 'TypeScript', 61.0)
# (292, 'xplat', 'Java', 18.0)
# (293, 'go-tpm', 'Go', 615.0)
# (294, 'guava-beta-checker', 'Java', 91.0)
# (295, 'google-authenticator-libpam', 'C', '1.9k')
# (296, 'spatial-media', 'Python', '2k')
# (297, 'jimfs', 'Java', '2.5k')
# (298, 'truth', 'Java', '2.8k')
# (299, 'longfellow-zk', 'C++', 983.0)
# (300, 'kernel-research', 'C++', 47.0)
# (301, 'bindiff', 'Java', '2.8k')
# (302, 'shifter', 'Go', 45.0)
# (303, 'cddlconv', 'TypeScript', 11.0)
# (304, 'coset', 'Rust', 38.0)
# (305, 'sbom-conformance', 'Go', 2.0)
# (306, 'brax', 'Jupyter Notebook', '2.9k')
# (307, 'starlark-go', 'Go', '2.6k')
# (308, 'GoogleSignIn-iOS', 'Objective-C', 667.0)
# (309, 'rust_icu', 'Rust', 128.0)
# (310, 'jsir', 'C++', 106.0)
# (311, 'walt', 'Java', 462.0)
# (312, 'meterstick', 'Jupyter Notebook', 109.0)
# (313, 'cpu_features', 'C++', '2.6k')
# (314, 'binexport', 'C++', '1.2k')
# (315, 'kotlin-fhir', 'Kotlin', 53.0)
# (316, 'saxml', 'Python', 146.0)
# (317, 'ever', 'Jupyter Notebook', 14.0)
# (318, 'sso-offloading', 'TypeScript', None)
# (319, 'kf', 'Go', 400.0)
# (320, 'vizier', 'Python', '1.6k')
# (321, 'instrumentsToPprof', 'Go', 52.0)
# (322, 'mozc-devices', 'C++', '2.7k')
# (323, 'ml_collections', 'Python', 996.0)
# (324, 'graph-renderer', None, 0.0)
# (325, 'toucan', 'C++', 48.0)
# (326, 'container-explorer', 'Go', 89.0)
# (327, 'googet', 'Go', 98.0)
# (328, 'google-api-objectivec-client-for-rest', 'Objective-C', 828.0)
# (329, 'desugar_jdk_libs', 'Java', 389.0)
# (330, 'uncertainty-baselines', 'Python', '1.6k')
# (331, 'bt-navi-tests', 'Python', 5.0)
# (332, 'capslock', 'Go', '1.1k')
# (333, 'go-tpm-tools', 'C', 271.0)
# (334, 'jax-cfd', 'Jupyter Notebook', 892.0)
# (335, 'p4-infra', 'C++', None)
# (336, 'kotlin_convert', 'Kotlin', 20.0)
# (337, 'built_collection.dart', 'Dart', 283.0)
# (338, 'quiver-dart', 'Dart', '1.1k')
# (339, 'pthreadpool', 'C++', 23.0)
# (340, 'webkit_inspection_protocol.dart', 'Dart', 33.0)
# (341, 'semantic-locators', 'JavaScript', 58.0)
# (342, 'brotli-wheels', None, 10.0)
# (343, 'openintent', None, 33.0)
# (344, 're2', 'C++', '9.5k')
# (345, 'bazel-common', 'Starlark', 91.0)
# (346, 'bughunters', None, 139.0)
# (347, 'filament-assets', 'Mathematica', None)
# (348, 'xarray-beam', 'Python', 158.0)
# (349, 'gsocguides', 'CSS', 474.0)
# (350, 'mpact-cheriot', 'C++', 6.0)
# (351, 'glazier', 'Python', '1.2k')
# (352, 'mpact-riscv', 'C++', 26.0)
# (353, 'tfp-causalimpact', 'Python', 133.0)
# (354, 'fscryptctl', 'C', 137.0)
# (355, 'capirca', 'Python', 839.0)
# (356, 'imt', 'C++', 5.0)
# (357, 'neper', 'C', 317.0)
# (358, 'autofdo', 'C++', 575.0)
# (359, 'ARC-GEN', 'Python', 33.0)
# (360, 'fresnel', 'Go', 55.0)
# (361, 'dart_cli_pkg', 'Dart', 61.0)
# (362, 'fiddle', 'Python', 364.0)
# (363, 'elemental2', 'Java', 167.0)
# (364, 'jsinterop-base', 'Java', 72.0)
# (365, 'jsinterop-annotations', 'Java', 21.0)
# (366, 'jsinterop-generator', 'Java', 82.0)
# (367, 'genie-for-sap-abap-ai-assistant-sample', 'ABAP', 26.0)
# (368, 'omaha-client', 'Rust', 6.0)
# (369, 'sbat-rs', 'Rust', 18.0)
# (370, 'authenticode-rs', 'Rust', 30.0)
# (371, 'gpt-disk-rs', 'Rust', 71.0)
# (372, 'hackable_diffusion', 'Python', 23.0)
# (373, 'zimtohrli', 'Jupyter Notebook', 172.0)
# (374, 'safevalues', 'TypeScript', 137.0)
# (375, 'uri.dart', 'Dart', 80.0)
# (376, 'mangle', 'Go', '2.9k')
# (377, 'mono_repo.dart', 'Dart', 165.0)
# (378, 'python-fire', 'Python', '28k')
# (379, 'gn-language-server', 'Rust', 18.0)
# (380, 'ragvis', None, None)
# (381, 'xarray-tensorstore', 'Python', 61.0)
# (382, 'flogger', 'Java', '1.5k')
# (383, 'breakpad', 'C++', '2.8k')
# (384, 'hotels-template-library', 'C++', 24.0)
# (385, 'google-ctf', 'Python', '4.8k')
# (386, 'process_runner', 'Dart', 20.0)
# (387, 'nsync', 'C', '1.2k')
# (388, 'quic-trace', 'C++', 119.0)
# (389, 'temporian', 'Python', 703.0)
# (390, 'mtail', 'Go', '4k')
# (391, 'obr', 'C++', 22.0)
# (392, 'turbinia', 'Python', 776.0)
# (393, 'google-java-format', 'Java', '6k')
# (394, 'addlicense', 'Go', 849.0)
# (395, 'GoogleAppMeasurement', 'Swift', 31.0)
# (396, 'rrg', 'Rust', 59.0)
# (397, 'evt-air-risk-aiaa-scitech-2026', 'Python', 2.0)
# (398, 'watchface', 'Kotlin', 52.0)
# (399, 'double-conversion', 'C++', '1.2k')
# (400, 'der-ascii', 'Go', 248.0)
# (401, 'inject-common', 'Java', 11.0)
# (402, 'jaxite', 'Python', 88.0)
# (403, 'airio', 'Python', 21.0)
# (404, 'buzzer', 'Go', 467.0)
# (405, 'jpegli', 'C++', 276.0)
# (406, 'ts-bridge', 'Go', 54.0)
# (407, 'slo-generator', 'Python', 546.0)
# (408, 'autobound', 'Python', 363.0)
# (409, 'pdsl-xray', 'Java', 2.0)
# (410, 'test-server', 'Go', 17.0)
# (411, 'sbsim', 'Python', 86.0)
# (412, 'tracey', 'Go', 6.0)
# (413, 'smbios-validation-tool', 'Go', 12.0)
# (414, 'pmax_best_practices_dashboard', 'Shell', 52.0)
# (415, 'pubmed-rag', 'Jupyter Notebook', 10.0)
# (416, 'loudness_ebur128', 'C++', 3.0)
# (417, 'python-proto-converter', 'Python', 15.0)
# (418, 'pathways-job', 'Go', 14.0)
# (419, 'humanio', 'JavaScript', 14.0)
# (420, 'anonymous-tokens', 'C++', 58.0)
# (421, 'eDistantObject', 'Objective-C', 176.0)
# (422, 'built_value.dart', 'Dart', 882.0)
# (423, 'fleetspeak', 'Go', 142.0)
# (424, 'yamlfmt', 'Go', '1.6k')
# (425, 'tf-shell', 'Python', 9.0)
# (426, 'rootcanal', 'C++', 30.0)
# (427, 'skcms', None, 3.0)
# (428, 'deepvariant', 'Python', '3.6k')
# (429, 'drjax', 'Python', 15.0)
# (430, 'jaxloop', 'Jupyter Notebook', 18.0)
# (431, 'private-join-and-compute', 'C++', 832.0)
# (432, 'gnxi', 'Python', 282.0)
# (433, 'winops', 'Go', 121.0)
# (434, 'intellij-community', 'Java', 12.0)
# (435, 'wireit', 'TypeScript', '6.3k')
# (436, 'aarch64-paging', 'Rust', 37.0)
# (437, 'synopsys-dw-uart', 'Rust', None)
# (438, 'command-fds', 'Rust', 41.0)
# (439, 'OpenSK', 'Rust', '3.2k')
# (440, 'capsem', 'Python', 0.0)
# (441, 'private-membership', 'C++', 49.0)
# (442, 'yapf', 'Python', '14k')
# (443, 'rune', 'C', '1.9k')
# (444, 'trillian-website', 'HTML', 12.0)
# (445, 'vanir', 'Python', 342.0)
# (446, 'cabbie', 'Go', 99.0)
# (447, 'travel-impact-model', None, 164.0)
# (448, 'nsjail', 'C++', '3.6k')
# (449, 'sandboxed-api', 'C++', '1.7k')
# (450, 'deepsomatic', None, 274.0)
# (451, 'licenseclassifier', 'Go', 339.0)
# (452, 'distbench', 'C++', 54.0)
# (453, 'ide-perf', 'Kotlin', 65.0)
# (454, 'native-pkcs11', 'Rust', 64.0)
# (455, 'mpact-sim', 'C++', 37.0)
# (456, 'webview-ads', 'HTML', None)
# (457, 'gematria', 'Python', 91.0)
# (458, 'taxinomia', 'Go', None)
# (459, 'opendocs', None, 199.0)
# (460, 'jaxopt', 'Python', '1k')
# (461, 'threat-team', 'YARA', 54.0)
# (462, 'generative-ai-docs', 'Jupyter Notebook', '2.2k')
# (463, 'oss-policies-info', None, 28.0)
# (464, 'cloud-forensics-utils', 'Python', 489.0)
# (465, 'play-unreal-engine-plugin', 'C++', 12.0)
# (466, 'security-testbeds', 'Tcl', 52.0)
# (467, 'amber', 'C++', 215.0)
# (468, 'proto-lens', 'Haskell', 497.0)
# (469, 'play-services-plugins', 'Java', 503.0)
# (470, 'packetdrill', 'C', 950.0)
# (471, 'codemirror.dart', 'Dart', 87.0)
# (472, 'emboss', 'Python', 82.0)
# (473, 'playground-elements', 'TypeScript', 625.0)
# (474, 'snippet-uiautomator', 'Java', 46.0)
# (475, 'slowjam', 'HTML', 252.0)
# (476, 'fswalker', 'Go', 109.0)
# (477, 'sanitizers', 'C', '12k')
# (478, 'reflectable.dart', 'Dart', 382.0)
# (479, 'private-compute-services', 'Java', 526.0)
# (480, 'llm-sidebar-with-context', 'JavaScript', 4.0)
# (481, 'mediapy', 'Jupyter Notebook', 441.0)
# (482, 'learn-oss-with-google', 'Python', 43.0)
# (483, 'google.github.io', 'HTML', 533.0)
# (484, 'minimalloc', 'C++', 175.0)
# (485, 'smccc', 'Rust', 8.0)
# (486, 's2a-proto', None, 0.0)
# (487, 's2a-go', 'Go', 25.0)
# (488, 'GoogleUtilities', 'Objective-C', 121.0)
# (489, 'mount-zip', 'C++', 221.0)
# (490, 'dnsmasq_exporter', 'Go', 184.0)
# (491, 'libultrahdr', 'C++', 262.0)
# (492, 'GTMAppAuth', 'Swift', 413.0)
# (493, 'ffn', 'Python', 339.0)
# (494, 'trax', 'Python', '8.3k')
# (495, 'mobly-wifi', 'Python', 7.0)
# (496, 'CausalImpact', 'R', '1.8k')
# (497, 'create-service-account', 'Python', 25.0)
# (498, 'wmt-mqm-human-evaluation', None, 96.0)
# (499, 'polymorphicDSL', 'Java', 12.0)
# (500, 'apitools', 'Python', 145.0)
# (501, 'flink-connector-gcp', 'Java', 12.0)
# (502, 'bundletool', 'Java', '3.9k')
# (503, 'rdma-unit-test', 'C++', 30.0)
# (504, 'kafel', 'C', 340.0)
# (505, 'GiftStick', 'Python', 142.0)
# (506, 'minja', 'C++', 198.0)
# (507, 'gin-config', 'Python', '2.1k')
# (508, 'quahog', 'Go', 2.0)
# (509, 'sagetv', 'Java', 280.0)
# (510, 'protobuf-gradle-plugin', 'Groovy', '1.8k')
# (511, 'struct2tensor', 'Python', 34.0)
# (512, 'material-design-icons', None, '53k')
# (513, 'closure-compiler-npm', 'JavaScript', 339.0)
# (514, 'allocation-instrumenter', 'Java', 487.0)
# (515, 'draco', 'C++', '7k')
# (516, 'jscin', 'JavaScript', 45.0)
# (517, 'kati', 'Rust', 994.0)
# (518, 'GoogleDataTransport', 'Objective-C', 53.0)
# (519, 'cql', 'Go', 94.0)
# (520, 'interop-ios-for-google-sdks', 'Objective-C', 13.0)
# (521, 'app-check', 'Objective-C', 31.0)
# (522, 'fully-homomorphic-encryption', 'C++', '3.6k')
# (523, 'strict-csp', 'TypeScript', 48.0)
# (524, 'jaxonnxruntime', 'Python', 125.0)
# (525, 'subcommands', 'Go', 784.0)
# (526, 'ukey2', 'Java', 48.0)
# (527, 'dataflow-ml-starter', 'Python', 24.0)
# (528, 'async-request-dispatcher-rs', 'Rust', 3.0)
# (529, 'virtual-broadcast-production-assistant', 'JavaScript', 16.0)
# (530, 'honggfuzz', 'C', '3.3k')
# (531, 'kctf', 'Go', 731.0)
# (532, 'gcp_scanner', 'Python', 341.0)
# (533, 'bigwheels', 'C++', 101.0)
# (534, 'web-game-samples', 'JavaScript', 56.0)
# (535, 'fleetspeak-rs', 'Rust', 10.0)
# (536, 'eng-edu', 'Jupyter Notebook', 734.0)
# (537, 'edward2', 'Jupyter Notebook', 702.0)
# (538, 'fuse-archive', 'C++', 223.0)
# (539, 'github-webhook-pubsub-bridge', 'Go', 6.0)
# (540, 'safe-mmio', 'Rust', 17.0)
# (541, 'percore', 'Rust', 8.0)
# (542, 'go-licenses', 'Go', 960.0)
# (543, 'pybind11clif', 'C++', 70.0)
# (544, 'shaderc-rs', 'Rust', 282.0)
# (545, 'closure-net', None, 3.0)
# (546, 'rax', 'Python', 335.0)
# (547, 'go-dap', 'Go', 133.0)
# (548, 'distributed_point_functions', 'C++', 77.0)
# (549, 'rust-scudo', 'Rust', 59.0)
# (550, 'casimir', 'Rust', None)
# (551, 'ota-analyzer', 'JavaScript', 13.0)
# (552, 'crumbles', 'Java', 5.0)
# (553, 'tuple.dart', 'Dart', 194.0)
# (554, 'grinder.dart', 'Dart', 266.0)
# (555, 'webdriver.dart', 'Dart', 141.0)
# (556, 'sync_http.dart', 'Dart', 17.0)
# (557, 'flutter-mediapipe', 'Dart', 270.0)
# (558, 'dart-basics', 'Dart', 164.0)
# (559, 'genc', 'C++', 63.0)
# (560, 'carfac', 'Jupyter Notebook', 131.0)
# (561, 'kube-startup-cpu-boost', 'Go', 508.0)
# (562, 'jni-bind', 'C++', 304.0)
# (563, 'autocxx', 'Rust', '2.5k')
# (564, 'ghc-source-gen', 'Haskell', 99.0)
# (565, 'tsunami-security-scanner-callback-server', 'Java', 18.0)
# (566, 'partner-ads-experience', None, 4.0)
# (567, 'fast-isotropic-median-filter', 'C++', 16.0)
# (568, 'ink-stroke-modeler', 'C++', 104.0)
# (569, 'cad_campaign_anomaly_detector', 'JavaScript', 11.0)
# (570, 'pcie_lmt', 'Go', 7.0)
# (571, 'llvm-memprof', 'C++', 4.0)
# (572, 'soql-tool', 'Apex', 0.0)
# (573, 'pl011-uart', 'Rust', 6.0)
# (574, 'saif-data', None, 4.0)
# (575, 'link-diver', 'TypeScript', 69.0)
# (576, 'wire', 'Go', '14k')
# (577, 'grpc-binary', 'Swift', 10.0)
# (578, 'kunit-docs', 'HTML', 29.0)
# (579, 'evolve-forms', 'Apex', 174.0)
# (580, 'matched_markets', 'Python', 94.0)
# (581, 'flow-lens', 'TypeScript', 71.0)
# (582, 'distributed_graph_flow', None, 0.0)
# (583, 'go-eventlog', 'Go', 15.0)
# (584, 'Serberus', None, 13.0)
# (585, 'node-gles', 'C++', 331.0)
# (586, 'co-op-4-all', 'TypeScript', 10.0)
# (587, 'data-driven-discretization-1d', 'Jupyter Notebook', 168.0)
# (588, 'howtodiv', 'Python', 8.0)
# (589, 'corpuscrawler', 'Python', 211.0)
# (590, 'accompanist', 'Kotlin', '7.8k')
# (591, 'proto-task-queue', 'Python', 10.0)
# (592, 'arm-gic', 'Rust', 38.0)
# (593, 'python-spanner-orm', 'Python', 40.0)
# (594, 'multichase', 'C', 146.0)
# (595, 'graph-mining', 'C++', 712.0)
# (596, 'executor.nvim', 'Lua', 153.0)
# (597, 's2-geometry-library-java', 'Java', 578.0)
# (598, 'gnostic', 'Go', '2.2k')
# (599, 'cluster-data', 'TeX', '1k')
# (600, 'cassowary.dart', 'Dart', 44.0)
# (601, 'speaker-id', 'Python', 436.0)
# (602, 'localtoast', 'Go', 114.0)
# (603, 'generative-ai-go', 'Go', 829.0)
# (604, 'if-this-then-ad', 'TypeScript', 99.0)
# (605, 'dynamicworld', 'Jupyter Notebook', 153.0)
# (606, 'effcee', 'C++', 102.0)
# (607, 'facade', 'Python', 133.0)
# (608, 'har2csv', 'JavaScript', 46.0)
# (609, 'reflow-list', 'TypeScript', 8.0)
# (610, 'model-viewer', 'TypeScript', '7.7k')
# (611, 'esamplusplus', 'Python', 4.0)
# (612, 'devlibrary', 'Vue', 194.0)
# (613, 'shoptimizer', 'Python', 48.0)
# (614, 'safe-active-record', 'Ruby', 18.0)
# (615, 'practical-inverse-rendering-of-textured-and-translucent-appearance', 'Python', 113.0)
# (616, 'deluca', 'Jupyter Notebook', 124.0)
# (617, 'wci', 'Python', 36.0)
# (618, 'csv-to-firestore', 'Python', 25.0)
# (619, 'tacotron', 'HTML', 540.0)
# (620, 'sequence-layers', 'Python', 46.0)
# (621, 'conversational-surveys', 'JavaScript', 6.0)
# (622, 'ippusb', 'Rust', 4.0)
# (623, 'rubik', 'Python', 28.0)
# (624, 'vbootrom', 'C', 16.0)
# (625, 'web-hv', 'JavaScript', 46.0)
# (626, 'safety-web', 'TypeScript', 27.0)
# (627, 'argh', 'Rust', '1.9k')
# (628, 'fedjax', 'Python', 266.0)
# (629, 'jsonnet', 'Jsonnet', '7.4k')
# (630, 'chrome-ssh-agent', 'Go', 274.0)
# (631, 'hrx-ruby', 'Ruby', 12.0)
# (632, 'smc-hello-world', 'C', None)
# (633, 'smc-common', 'C', None)
# (634, 'deku', 'Go', 6.0)
# (635, 'code-review-bot', 'Go', 101.0)
# (636, 'truestreet', 'Go', 42.0)
# (637, 'python-card-framework', 'Python', 22.0)
# (638, 'ruy', 'C++', 316.0)
# (639, 'wuffs', 'C', '4.7k')
# (640, 'gmail-oauth2-tools', 'Python', 463.0)
# (641, 'triage-party', 'Go', 521.0)
# (642, 'web-api-gateway', 'Go', 46.0)
# (643, 'payjs', 'JavaScript', 7.0)
# (644, 'gonids', 'Go', 189.0)
# (645, 'flyweights', 'Rust', 2.0)
# (646, 'litmus', 'Vue', 38.0)
# (647, 'gtest-parallel', 'Python', 454.0)
# (648, 'ml-edu', 'Python', 6.0)
# (649, 'automotive-design-compose-protos', None, 0.0)
# (650, 'swissgl', 'JavaScript', '1.2k')
# (651, 'rde-tester', 'C++', None)
# (652, 'refvnli', 'JavaScript', 0.0)
# (653, 'CoMMA', 'Rust', 10.0)
# (654, 'fsl-gaming', 'JavaScript', 25.0)
# (655, 'terraform-google-sqlserver', 'PowerShell', 3.0)
# (656, 'cost-attribution-solution', 'HCL', 37.0)
# (657, 'lmeval', 'Python', 235.0)
# (658, 'tachometer', 'TypeScript', 725.0)
# (659, 'ios-webkit-debug-proxy', 'C', '6.1k')
# (660, 'apilark', None, 6.0)
# (661, 'tcli', 'Python', 9.0)
# (662, 'app-resource-bundle', None, 155.0)
# (663, 'recaptcha', 'PHP', '3.5k')
# (664, 'ent', 'Go', 75.0)
# (665, 'CommonLoopUtils', 'Jupyter Notebook', 358.0)
# (666, 'ebpf-transport-monitoring', 'Go', 23.0)
# (667, 'rago', 'Python', 21.0)
# (668, 'aukera', 'Go', 41.0)
# (669, 'open-location-code', 'Java', '4.3k')
# (670, 'jaxcam', 'Python', 13.0)
# (671, 'content_recommendation_using_word2vec', 'Python', 27.0)
# (672, 'safehtml', 'Go', 373.0)
# (673, 'forest-data-partnership', 'Jupyter Notebook', 35.0)
# (674, 'lightweight_mmm', 'Python', '1k')
# (675, 'gazoo-device', 'Python', 23.0)
# (676, 'bt-test-interfaces', 'Python', 14.0)
# (677, 'avatar', 'Python', 20.0)
# (678, 'paranoid_crypto', 'Python', 796.0)
# (679, 'proto-splitter', 'C++', None)
# (680, 'cadvisor', 'Go', '19k')
# (681, 'unblocking-detail-caption', 'HTML', None)
# (682, 'auto-arborist', 'Jupyter Notebook', 13.0)
# (683, 'qkeras', 'Python', 578.0)
# (684, 'pts-bot', 'Rust', 4.0)
# (685, 'private-compute-libraries', 'Kotlin', 34.0)
# (686, 'vroom', 'Python', 274.0)
# (687, 'libaddressinput', 'C++', 603.0)
# (688, 'android-key-attestation', 'Java', 212.0)
# (689, 'dv360-duplicator', 'TypeScript', 20.0)
# (690, 'eiffel', 'C', 5.0)
# (691, 'skyline_rl_lab', 'Jupyter Notebook', 6.0)
# (692, 'pseudo-identity-provider', 'Go', 9.0)
# (693, 'llvm-premerge-checks', 'Python', 43.0)
# (694, 'go-configfs-tsm', 'Go', 8.0)
# (695, 'grr', 'Python', '5k')
# (696, 'sandwiched_compression', 'Jupyter Notebook', 48.0)
# (697, 'gemma_pytorch', 'Python', '5.6k')
# (698, 'go-safeweb', 'Go', '1.5k')
# (699, 'visualblocks', 'TypeScript', '1.3k')
# (700, 'codesearch', 'Go', '3.9k')
# (701, 'webauthndemo', 'TypeScript', 621.0)
# (702, 'UIforETW', 'C++', '1.6k')
# (703, 'hiba', 'C', 384.0)
# (704, 'pyink', 'Python', 279.0)
# (705, 'vk-layer-for-rust', 'Rust', 14.0)
# (706, 'liblc3', 'C', 225.0)
# (707, 'taqo-paco', 'Dart', 12.0)
# (708, 'jse4conf', 'Java', 6.0)
# (709, 'synthmark', 'C++', 55.0)
# (710, 'df-conformer', 'HTML', 31.0)
# (711, 'zetasketch', 'Java', 162.0)
# (712, 'cairn', 'C++', 5.0)
# (713, 'agi', 'Go', '1k')
# (714, 'lullaby', 'C++', '1.2k')
# (715, 'visqol', 'C++', 835.0)
# (716, 'glog', 'C++', '7.3k')
# (717, 'uvq', 'Python', 119.0)
# (718, 'aegis_cipher', 'C++', 25.0)
# (719, 'consent-based-conversion-adjustments', 'Python', 25.0)
# (720, 'containerdbg', 'C', 74.0)
# (721, 'Stereoscopic-Video-Generation-via-Denoising-Frame-Matrix', 'Python', 7.0)
# (722, 'iopddl', 'C++', 23.0)
# (723, 'badwolf-drivers', 'Go', 22.0)
# (724, 'project-euphonia-app', 'Dart', 28.0)
# (725, 'badwolf', 'Go', 984.0)
# (726, 'fruit', 'C++', '1.9k')
# (727, 'sa360-bigquery-bootstrapper', 'Python', 6.0)
# (728, 'gemma-unity-plugin', 'C#', 79.0)
# (729, 'gemma-journey', 'C#', 28.0)
# (730, 'feabench', 'Python', 4.0)
# (731, 'hashr', 'Go', 126.0)
# (732, 'regexpand', 'Go', 8.0)
# (733, 'myelin-acorn-electron-hardware', 'Python', 59.0)
# (734, 'vscode-vnc', 'TypeScript', 5.0)
# (735, 'pica', 'Python', 55.0)
# (736, 'strangemeadowlark', 'Rust', 3.0)
# (737, 'note-maps', 'Go', 129.0)
# (738, 'curie', 'Jupyter Notebook', 28.0)
# (739, 'mobly-cros', 'Python', 2.0)
# (740, 'go-tika', 'Go', 253.0)
# (741, 'textfsm', 'Python', '1.2k')
# (742, 'sherlock', 'Python', 8.0)
# (743, 'go-tspi', 'Go', 62.0)
# (744, 'kernel-sanitizers', 'Python', 468.0)
# (745, 'file-header', 'Rust', 19.0)
# (746, 'extra-keyboards-for-chrome-os', 'JavaScript', 214.0)
# (747, 'libprotobuf-mutator', 'C++', 633.0)
# (748, 'crc32c', 'C++', 498.0)
# (749, 'codeworld', 'Haskell', '1.3k')
# (750, 'smali', 'Java', 324.0)
# (751, 'android-riscv64', None, 242.0)
# (752, 'unisim', 'Python', 144.0)
# (753, 'ml-metadata', 'C++', 666.0)
# (754, 'kmsan', 'C', 417.0)
# (755, 'play-asset-delivery-unity', 'C#', 13.0)
# (756, 'play-appbundle-unity', 'C#', 8.0)
# (757, 'file-based-test-driver', 'C++', 13.0)
# (758, 'oauth2l', 'Go', 708.0)
# (759, 'ads-privacy', None, 408.0)
# (760, 'trusted-types-helper', 'TypeScript', 11.0)
# (761, 'search-in-apps', 'Swift', 4.0)
# (762, 'eslint-config-google', 'JavaScript', '1.8k')
# (763, 'go-replayers', 'Go', 432.0)
# (764, 'uVkCompute', 'C++', 256.0)
# (765, 'dfdewey', 'Python', 19.0)
# (766, 'CFU-Playground', 'Verilog', 535.0)
# (767, 'sqlcommenter', 'PHP', 616.0)
# (768, 'picatrix', 'Python', 51.0)
# (769, 'shadertrap', 'C++', 12.0)
# (770, 'lldb-eval', 'C++', 86.0)
# (771, 'pasta', 'Python', 359.0)
# (772, 'LogicLM', 'HTML', 29.0)
# (773, 'wuffs-mirror-release-c', 'C', 38.0)
# (774, 'image_mix', 'Python', 16.0)
# (775, 'page-alloc-bench', 'Go', 4.0)
# (776, 'grizzly', 'Python', 69.0)
# (777, 'tf-quant-finance', 'Python', '5.1k')
# (778, 'coding-with-chrome', 'JavaScript', 530.0)
# (779, 'html-to-jsonld-converter', 'Python', 5.0)
# (780, 'gopacket', 'Go', '6.7k')
# (781, 'RB-Modulation', 'Jupyter Notebook', 402.0)
# (782, 'briolette', 'Rust', 67.0)
# (783, 'bbr', None, '5.8k')
# (784, 'py-lab-hal', 'Python', 12.0)
# (785, 'bsynth', 'C++', 20.0)
# (786, '.github', None, 109.0)
# (787, 'snowflake-to-bq-data-transfer-tool', 'Java', 3.0)
# (788, 'password-alert', 'JavaScript', 321.0)
# (789, 'moodle-on-gcp', 'Shell', 72.0)
# (790, 'glance-experimental-tools', 'Kotlin', 185.0)
# (791, 'myanmar-tools', 'Java', 255.0)
# (792, 'k8s-digester', 'Go', 154.0)
# (793, 'splice', 'Go', 65.0)
# (794, 'cc-device-plugin', 'Go', 4.0)
# (795, 'project-OCEAN', 'Python', 55.0)
# (796, 'git-pull-request-mirror', 'Go', 94.0)
# (797, 'weasel', 'Go', 66.0)
# (798, 'parse-ego4d', 'Jupyter Notebook', 7.0)
# (799, 'deepconsensus', 'Python', 251.0)
# (800, 'deeppolisher', 'Jupyter Notebook', 94.0)
# (801, 'makerspace-auth', 'Python', 66.0)
# (802, 'material-design-lite', 'HTML', '32k')
# (803, 'patrick', 'R', 143.0)
# (804, 'xr-objects', 'C#', 162.0)
# (805, 'dlc-insight-lab', 'JavaScript', None)
# (806, 'j2cl-protobuf', 'JavaScript', 25.0)
# (807, 'yarsa', 'Go', None)
# (808, 'googlesre', 'TypeScript', 167.0)
# (809, 'android-auto-companion-android', 'Kotlin', 26.0)
# (810, 'automl', 'Jupyter Notebook', '6.4k')
# (811, 'gdb_gcore_point', 'Python', 2.0)
# (812, 'serde_json5', 'Rust', 41.0)
# (813, 'emoji-scavenger-hunt', 'TypeScript', 819.0)
# (814, 'android-auto-companion-ios', 'Swift', 16.0)
# (815, 'library-wrapper-unity-common', 'C#', 7.0)
# (816, 'lottie-tools', 'Rust', 2.0)
# (817, 'speedy', 'C++', 35.0)
# (818, 'pebble', 'C', '4.9k')
# (819, 'volley', 'Java', '3.4k')
# (820, 'open-sztp', 'Go', 11.0)
# (821, 'pyu2f', 'Python', 84.0)
# (822, 'biva', 'C++', 6.0)
# (823, 'marl', 'C++', '2k')
# (824, 'cppdap', 'C++', 182.0)
# (825, 'uem_poc', 'TypeScript', 3.0)
# (826, 'new-project', None, 234.0)
# (827, 'go-cmp', 'Go', '4.5k')
# (828, 'mlir-hs', 'Haskell', 118.0)
# (829, 'webrisk', 'Go', 78.0)
# (830, 'csp-evaluator', 'TypeScript', 373.0)
# (831, 'multichannel-audio-tools', 'C++', 95.0)
# (832, 'pprof-nodejs', 'JavaScript', 287.0)
# (833, 'hctr2', 'C', 37.0)
# (834, 'santa-tracker-web', 'JavaScript', 641.0)
# (835, 'jira-to-issues', 'TypeScript', 18.0)
# (836, 'best', 'Rust', 137.0)
# (837, 'alu-api', 'Jupyter Notebook', None)
# (838, 'haskell-indexer', 'Haskell', 101.0)
# (839, 'latexify_py', 'Python', '7.6k')
# (840, 'abseil-cpp-binary', 'Swift', 16.0)
# (841, 'fuzzbench', 'Python', '1.2k')
# (842, 'jarjar', 'Java', 90.0)
# (843, 'xdtk', 'Java', 38.0)
# (844, 'play-integrity-unity', 'C#', 10.0)
# (845, 'play-in-app-reviews-unity', 'C#', 12.0)
# (846, 'play-in-app-updates-unity', 'C#', 3.0)
# (847, 'santa', 'Objective-C++', '4.5k')
# (848, 'play-core-unity', 'C#', 3.0)
# (849, 'android-auto-companion-app', 'Dart', 15.0)
# (850, 'orbit', 'C++', '4.3k')
# (851, 'leveldb', 'C++', '38k')
# (852, 'ctrdac', 'Go', 13.0)
# (853, 'mail-importer', 'Java', 264.0)
# (854, 'deck', 'Go', 56.0)
# (855, 'unsmear', 'C++', 95.0)
# (856, 'library-wrapper-unity-openjdk8', 'C#', 7.0)
# (857, 'calblink', 'Go', 43.0)
# (858, 'kir-holiday-lights', 'Shell', 19.0)
# (859, 'io-connect-2024-ui-workshop', 'CSS', 44.0)
# (860, 'snaplayout-for-xmonad', 'Haskell', 6.0)
# (861, 'dfiq', 'Python', 294.0)
# (862, 'git-tree', 'Rust', 45.0)
# (863, 'learn_unsafe_rust', None, 279.0)
# (864, 'archat', 'TypeScript', 94.0)
# (865, 'summit-ast', 'Kotlin', 42.0)
# (866, 'rust-p9', 'Rust', 43.0)
# (867, 'spiqa', 'Python', 70.0)
# (868, 'oxsea', 'Rust', 2.0)
# (869, 're2j', 'Java', '1.2k')
# (870, 'megalista', 'Python', 138.0)
# (871, 'serde_json_lenient', 'Rust', 25.0)
# (872, 'bulk-actions-framework', 'Apex', None)
# (873, 'rag-playground', 'Python', 41.0)
# (874, 'agi-dev-releases', 'Shell', 35.0)
# (875, 'fhir-app-examples', 'Kotlin', 54.0)
# (876, 'shopping_insider', 'Python', 29.0)
# (877, 'gnostic-grpc', 'Go', 314.0)
# (878, 'acjs', 'Go', 10.0)
# (879, 'go-react', 'Go', 38.0)
# (880, 'broken-dns', 'Go', 22.0)
# (881, 'xtoproto', 'Go', 57.0)
# (882, 'martian', 'Go', '2k')
# (883, 'recursive-version-control-system', 'Go', 31.0)
# (884, 'spdmd', 'C++', 0.0)
# (885, 'bulk_fhir_tools', 'Go', 63.0)
# (886, 'ondc-opencommerce', 'Go', 24.0)
# (887, 'goblet', 'Go', 181.0)
# (888, 'webpackager', 'Go', 75.0)
# (889, 'apt-golang-s3', 'Go', 49.0)
# (890, 'fhir-dbt-analytics', 'Shell', 58.0)
# (891, 'vxsig', 'C++', 284.0)
# (892, 'traceur-compiler', 'JavaScript', '8.2k')
# (893, 'vimscript-language-server', 'Rust', 401.0)
# (894, 'cpp-from-the-sky-down', 'HTML', 276.0)
# (895, 'tree-math', 'Python', 202.0)
# (896, 'go-streaming-globber', 'Go', 6.0)
# (897, 'clusterfuzzlite', None, 508.0)
# (898, 'ads-bi-suite', 'Shell', 18.0)
# (899, 'tcpgpudmarxd', 'C++', 9.0)
# (900, 'play-common-unity', 'C#', None)
# (901, 'play-unity-plugins', 'C#', 465.0)
# (902, 'codex', 'Jupyter Notebook', 67.0)
# (903, 'sre_yield', 'Python', 187.0)
# (904, 'lintush', 'JavaScript', 59.0)
# (905, 'emoji-segmenter', 'C', 64.0)
# (906, 'unity-anr-plugin', 'Java', 5.0)
# (907, 'imageinwords', 'JavaScript', 223.0)
# (908, 'android-emulator-container-scripts', 'Python', '2k')
# (909, 'werm', 'C', 47.0)
# (910, 'season-of-docs', None, 579.0)
# (911, 'uuid', 'Go', '5.9k')
# (912, 'android-auto-companion-calendarsync-ios', 'Swift', 6.0)
# (913, 'ionosphere', 'Jupyter Notebook', 3.0)
# (914, 'takeout', None, 11.0)
# (915, 'promises', 'Objective-C', '3.8k')
# (916, 'iba-opt-out-plugin', 'JavaScript', None)
# (917, 'dopamine', 'Jupyter Notebook', '11k')
# (918, 'docci', 'HTML', 3.0)
# (919, 'compute-virtual-ethernet-dpdk', 'C', 11.0)
# (920, 'angular-directed-graph', 'TypeScript', 18.0)
# (921, 'skywater-pdk', 'Python', '3.3k')
# (922, 'safearchive', 'Go', 64.0)
# (923, 'gts', 'TypeScript', '5.2k')
# (924, 'fuzzing', 'C++', '3.7k')
# (925, 'slang-gaussian-rasterization', 'Python', 363.0)
# (926, 'talkback', 'Java', 488.0)
# (927, 'langsvr', 'C++', 9.0)
# (928, 'coroutine-stacks', 'Kotlin', 144.0)
# (929, 'devtools-driver', 'Java', 16.0)
# (930, 'account-provisioning-for-google-apps', 'Java', 51.0)
# (931, 'chicago-brick', 'TypeScript', 161.0)
# (932, 'tour-of-wgsl', 'TypeScript', 141.0)
# (933, 'crfs', 'Go', '1.4k')
# (934, 'cql-on-beam', 'Java', 12.0)
# (935, 'capsicum-test', 'C++', 45.0)
# (936, 'docker-explorer', 'Python', 548.0)
# (937, 'graphicsfuzz', 'Java', 594.0)
# (938, 'CodeCity', 'JavaScript', 193.0)
# (939, 'moriarty', 'C++', 6.0)
# (940, 'uis-rnn', 'Python', '1.6k')
# (941, 'purr', 'Shell', 155.0)
# (942, 'karma-webkit-launcher', 'JavaScript', 12.0)
# (943, 'yaml-ui-editor', 'Java', 32.0)
# (944, 'supl-client', 'Java', 71.0)
# (945, 'robotstxt-spec-test', 'Java', 23.0)
# (946, 'step49-2020', 'Java', 3.0)
# (947, 'robotstxt-java', 'Java', 47.0)
# (948, 'exposure-notifications-private-analytics-ingestion', 'Java', 12.0)
# (949, 'play-work', 'Java', 85.0)
# (950, 'grr-doc', 'Shell', 307.0)
# (951, 'eng-practices', None, '20k')
# (952, 'tec-web-assignments', 'JavaScript', 12.0)
# (953, 'webdriver-shadow-dom', 'Kotlin', 2.0)
# (954, 'drive-file-search-fix', 'JavaScript', 5.0)
# (955, 'gousb', 'Go', 917.0)
# (956, 'bayesnf', 'Python', 142.0)
# (957, 'funke-eudi-wallet-prototype', 'Kotlin', 3.0)
# (958, 'vimdoc', 'Python', 304.0)
# (959, 'paseos', 'JavaScript', 15.0)
# (960, 'tsunami', 'TypeScript', 9.0)
# (961, 'hrx', 'SCSS', 49.0)
# (962, 'english--', 'JavaScript', 7.0)
# (963, 'clif', 'C++', 981.0)
# (964, 'grrshell', 'Python', 7.0)
# (965, 'cdc-file-transfer', 'C++', '3.4k')
# (966, 'devops-governance', None, 83.0)
# (967, 'google-visualization', 'TypeScript', 14.0)
# (968, 'price_visibility_booster', 'JavaScript', 2.0)
# (969, 'vim-codefmt', 'Vim Script', '1.1k')
# (970, 'project-gameface', 'Java', 617.0)
# (971, 'Vulkan-Errata', 'Python', 5.0)
# (972, 'ad_language_monitor', 'JavaScript', 5.0)
# (973, 'cell_img', 'Jupyter Notebook', 8.0)
# (974, 'souper', 'C++', '2.3k')
# (975, 'audio-to-tactile', 'C', 103.0)
# (976, 'secrets-gradle-plugin', 'Kotlin', '1.3k')
# (977, 'madi', 'Python', 78.0)
# (978, 'google-api-javascript-client', 'CSS', '3.4k')
# (979, 'btree', 'Go', '4.1k')
# (980, 'it-cert-automation-practice', 'Python', 985.0)
# (981, 'sxg-rs', 'Rust', 85.0)
# (982, 'lyra', 'C++', '3.9k')
# (983, 'schemarama', 'JavaScript', 146.0)
# (984, 'premium-vs-standard-network-latency', 'Shell', 4.0)
# (985, 'lut3d_utils', 'Python', 11.0)
# (986, 'rust-derive-fuzztest', 'Rust', 18.0)
# (987, 'real-time-intelligence-workshop', 'Jupyter Notebook', 27.0)
# (988, 'ghost-kernel', 'C', 227.0)
# (989, 'ansicolor-dart', 'Dart', 104.0)
# (990, 'libnop', 'C++', 576.0)
# (991, 'zopfli', 'C++', '3.6k')
# (992, 'flutter.widgets', 'Dart', '1.4k')
# (993, 'lifetime_value', 'Jupyter Notebook', 365.0)
# (994, 'ExoPlayer', 'Java', '22k')
# (995, 'woff2', 'C++', '1.7k')
# (996, 'pwlfit', 'Jupyter Notebook', 40.0)
# (997, 'haloquest', 'Jupyter Notebook', 23.0)
# (998, 'robotstxt', 'C++', '3.4k')
# (999, 'closure-library', 'JavaScript', '4.9k')
# (1000, 'omaha', 'C++', '2.6k')
# (1001, 'pycnite', 'Python', 26.0)
# (1002, 'model_search', 'Python', '3.3k')
# (1003, 'shopping-markup', 'Python', 49.0)
# (1004, 'resultstoreui', 'Python', 12.0)
# (1005, 'sg2im', 'Python', '1.3k')
# (1006, 'namebench', 'Go', 923.0)
# (1007, 'flight-lab', 'Python', 15.0)
# (1008, 'nccl-plugin-gpudirecttcpx', 'C++', 14.0)
# (1009, 'zazu', 'TypeScript', 21.0)
# (1010, 'codewords', 'TypeScript', 11.0)
# (1011, 'voice-builder', 'JavaScript', 679.0)
# (1012, 'dynamic-form', 'TypeScript', 30.0)
# (1013, 'werewolf_arena', 'Python', 40.0)
# (1014, 'cargo-raze', 'Rust', 481.0)
# (1015, 'safetext', 'Go', 150.0)
# (1016, 'daguerreotype', 'TypeScript', 9.0)
# (1017, 'sgtm-migrator', 'TypeScript', 17.0)
# (1018, 'BIG-bench', 'Python', '3.1k')
# (1019, 'feedloader', 'Python', 13.0)
# (1020, 'wikiloop-explorer', 'Vue', 8.0)
# (1021, 'nodejs-container-image-builder', 'TypeScript', 73.0)
# (1022, 'node-fastify-auto-push', 'TypeScript', 101.0)
# (1023, 'streetview-publish-client-libraries', 'Java', 19.0)
# (1024, 'defi-for-good-contracts', 'TypeScript', 14.0)
# (1025, 'oodle-demo', 'HTML', 83.0)
# (1026, 'making_with_ml', 'Jupyter Notebook', 348.0)
# (1027, 'centaur', 'TypeScript', 12.0)
# (1028, 'poseshield-tfjs', 'Vue', 14.0)
# (1029, 'personfinder', 'Python', 540.0)
# (1030, 'ai_assisted_display_creative', 'Python', 16.0)
# (1031, 'automated-native-creatives', 'TypeScript', 16.0)
# (1032, 'budoux-illustrator-script', 'TypeScript', 20.0)
# (1033, 'aoss-django-sample-starter-project', 'Shell', 6.0)
# (1034, 'nanopb-podspec', 'Ruby', 7.0)
# (1035, 'setfilters', 'Java', 10.0)
# (1036, 'agamotto', 'Python', 18.0)
# (1037, 'balloon-learning-environment', 'Python', 125.0)
# (1038, 'seatera', 'Python', 18.0)
# (1039, 'diffseg', 'Jupyter Notebook', 327.0)
# (1040, 'window-mirror', 'C#', 18.0)
# (1041, 'keyword_factory', 'Python', 41.0)
# (1042, 'merchant_center_repor_builder', 'Python', 11.0)
# (1043, 'inspiration_tree', 'Jupyter Notebook', 77.0)
# (1044, 'brain-tokyo-workshop', 'Jupyter Notebook', '1.3k')
# (1045, 'taxonomy_wizard', 'Python', 13.0)
# (1046, 'mandiant-ti-client', 'Python', 18.0)
# (1047, 'vertex-pipelines-boilerplate', 'Python', 10.0)
# (1048, 'project_cartesian', 'Python', 20.0)
# (1049, 'android-emulator-webrtc', 'JavaScript', 149.0)
# (1050, 'password-sync-support-tool', 'VBScript', 34.0)
# (1051, 'jsonapi', 'Go', '1.4k')
# (1052, 'ad-manager-alerter', 'Python', 27.0)
# (1053, 'looker-studio-dashboard-cloner', 'TypeScript', 36.0)
# (1054, 'gcp-scc-iac-validation-utils', 'Go', 2.0)
# (1055, 'iconvg', 'C', 683.0)
# (1056, 'playhvz', 'Kotlin', 26.0)
# (1057, 'assetMG', 'TypeScript', 7.0)
# (1058, 'bulkan', 'TypeScript', 7.0)
# (1059, 'evojax', 'Jupyter Notebook', 923.0)
# (1060, 'telluride_decoding', 'Python', 14.0)
# (1061, 'font-go', 'Go', 54.0)
# (1062, 'java-time-client', 'Java', 18.0)
# (1063, 'project-euphonia-audiotool', 'TypeScript', 27.0)
# (1064, 'task-oriented-queries', None, 5.0)
# (1065, 'peripheral-customization-pwa', 'TypeScript', 7.0)
# (1066, 'protobuf-extensibility-for-burp', 'Python', 88.0)
# (1067, 'eventid-js', 'TypeScript', 78.0)
# (1068, 'node-h2-auto-push', 'TypeScript', 328.0)
# (1069, 'js-green-licenses', 'TypeScript', 181.0)
# (1070, 'gasket-driver', 'C', 108.0)
# (1071, 'wikiloop-doublecheck', 'TypeScript', 83.0)
# (1072, 'data-layer-helper', 'JavaScript', 440.0)
# (1073, 'dana', 'JavaScript', 117.0)
# (1074, 'accname', 'TypeScript', 34.0)
# (1075, 'libhidtelephony', 'TypeScript', 12.0)
# (1076, 'incremental-dom', 'TypeScript', '3.5k')
# (1077, 'pixelate', 'TypeScript', 54.0)
# (1078, 'conversion-audit', 'TypeScript', 5.0)
# (1079, 'data-quality-monitor', 'TypeScript', 38.0)
# (1080, 'product-dsa', 'Python', 12.0)
# (1081, 'react-schemaorg', 'TypeScript', 506.0)
# (1082, 'android-management-api-samples', 'Jupyter Notebook', 34.0)
# (1083, 'creative-screenshots', 'TypeScript', 17.0)
# (1084, 'dqm', 'Python', 27.0)
# (1085, 'fusion-tables-archive-visualizer', 'TypeScript', 33.0)
# (1086, 'nodejs-wiki', 'JavaScript', 17.0)
# (1087, 'assortment-quality-for-shopping-ads', 'Python', 8.0)
# (1088, 'eleventy-high-performance-blog', 'JavaScript', '4.1k')
# (1089, 'uafcs', 'Python', 4.0)
# (1090, 'vsf-time-series', 'Python', 30.0)
# (1091, 'oculi', 'Jupyter Notebook', 63.0)
# (1092, 'android-uiconductor', 'Java', 125.0)
# (1093, 'tamperchrome', 'TypeScript', '4.2k')
# (1094, 'gov-meetings-made-searchable', 'Python', 33.0)
# (1095, 'patents-public-data', 'Jupyter Notebook', 626.0)
# (1096, 'tweakr', 'JavaScript', 26.0)
# (1097, 'ngrx-visualizer', 'TypeScript', 23.0)
# (1098, 'mweb-analysis-tools', 'JavaScript', 8.0)
# (1099, 'fusion-tables-drive-export', 'TypeScript', 7.0)
# (1100, 'vscode-zxdb', 'TypeScript', 4.0)
# (1101, 'gtasks-md', 'Python', 74.0)
# (1102, 'triggerator', 'TypeScript', 11.0)
# (1103, 'service-worker-detector', 'JavaScript', 183.0)
# (1104, 'cronet-transport-for-okhttp', 'Java', 523.0)
# (1105, 'ditto-mocks', 'Apex', 97.0)
# (1106, 'gps-measurement-tools', 'Java', 802.0)
# (1107, 'stijl', 'JavaScript', 43.0)
# (1108, 'schedviz', 'Go', 530.0)
# (1109, 'grassland', 'TypeScript', 10.0)
# (1110, 'synthesizer-io', 'Rust', 36.0)
# (1111, 'eslint-closure', 'JavaScript', 33.0)
# (1112, 'intermock', 'TypeScript', '1.2k')
# (1113, 'mpact-sim-codelabs', 'C++', 4.0)
# (1114, 'pybadges', 'Python', 498.0)
# (1115, 'uv-metrics', 'Python', 13.0)
# (1116, 'caliban', 'Python', 500.0)
# (1117, 'verilogpp', 'Perl', 17.0)
# (1118, 't5patches', 'Python', 12.0)
# (1119, 'vpn-libraries', 'C++', 554.0)
# (1120, 'go-p11-kit', 'Go', 93.0)
# (1121, 'ngx_brotli', 'C', '2.2k')
# (1122, 'psp', 'C', 276.0)
# (1123, 'google-sql-syntax-ts', 'TypeScript', 9.0)
# (1124, 'fishy-pdf', 'Python', 11.0)
# (1125, 'dv360-spend-monitoring-tool', 'JavaScript', 6.0)
# (1126, 'diff-match-patch', 'Python', '8k')
# (1127, 'hi-lassie', 'Python', 24.0)
# (1128, 'lassie', 'Python', 53.0)
# (1129, 'lkml-gerrit-bridge', 'Python', 7.0)
# (1130, 'lecam-gan', 'Jupyter Notebook', 165.0)
# (1131, 'prog-edu-assistant', 'Jupyter Notebook', 33.0)
# (1132, 'har-sanitizer', 'Python', 73.0)
# (1133, 'pre-commit-tool-hooks', 'Python', 38.0)
# (1134, 'jsaction', 'JavaScript', '1.1k')
# (1135, 'deepmac', 'HTML', 5.0)
# (1136, 'game-changing-assets', 'Jupyter Notebook', 3.0)
# (1137, 'framework-for-osdu', 'Java', 19.0)
# (1138, 'hintless_pir', 'C++', 22.0)
# (1139, 'jwt_verify_lib', 'C++', 44.0)
# (1140, 'prompt-to-prompt', 'Jupyter Notebook', '3.4k')
# (1141, 'how-unique-is-whose-web-browser', 'Jupyter Notebook', 2.0)
# (1142, 'brunsli', 'C++', 745.0)
# (1143, 'gapid', 'Go', '2.2k')
# (1144, 'report2bq', 'Python', 13.0)
# (1145, 'brandometer', 'Python', 10.0)
# (1146, 'ldif', 'Python', 320.0)
# (1147, 'pawn', 'C++', 337.0)
# (1148, 'empirical_calibration', 'Jupyter Notebook', 45.0)
# (1149, 'shuwa', 'Python', 143.0)
# (1150, 'tabletopaudio-action', 'TypeScript', 9.0)
# (1151, 'hypernerf', 'Python', 943.0)
# (1152, 'importlab', 'Python', 177.0)
# (1153, 'ota-generator', 'Python', 24.0)
# (1154, 'ai_video_dubbing', 'Python', 50.0)
# (1155, 'prefab', 'Kotlin', 229.0)
# (1156, 'starthinker', 'Python', 173.0)
# (1157, 'golden-path-for-app-delivery', 'Go', 18.0)
# (1158, 'ringli', 'C++', 11.0)
# (1159, 'oatts', 'JavaScript', 141.0)
# (1160, 'web-starter-kit', 'HTML', '18k')
# (1161, 'nerfies', 'Python', '1.9k')
# (1162, 'flexbox-layout', 'Kotlin', '18k')
# (1163, 'cityhash', 'Shell', '1.2k')
# (1164, 'intellij-gn-plugin', 'Kotlin', 15.0)
# (1165, 'safebrowsing', 'Go', 488.0)
# (1166, 'AEUX', 'JavaScript', 541.0)
# (1167, 'highwayhash', 'C++', '1.6k')
# (1168, 'amot', 'Shell', 3.0)
# (1169, 'licensecheck', 'Go', 483.0)
# (1170, 'osdetector-gradle-plugin', 'Java', 116.0)
# (1171, 'permhash', 'Python', 44.0)
# (1172, 'flaxformer', 'Python', 363.0)
# (1173, 'GTXiLib', 'Objective-C', 232.0)
# (1174, 'esh', 'C', 331.0)
# (1175, 'quota-monitoring-solution', 'Java', 52.0)
# (1176, 'common-multicloud-runtime', None, 0.0)
# (1177, 'cmrt', None, None)
# (1178, 'coding-with-chrome-libraries', 'JavaScript', 24.0)
# (1179, 'macops-MOLXPCConnection', 'Objective-C', 26.0)
# (1180, 'macops-MOLAuthenticatingURLSession', 'Objective-C', 23.0)
# (1181, 'macops-molcodesignchecker', 'Objective-C', 33.0)
# (1182, 'macops-molcertificate', 'Objective-C', 36.0)
# (1183, 'example-demos-for-msft-workloads', 'HCL', 16.0)
# (1184, 'python-adb', 'Python', '1.8k')
# (1185, 'cronutils', 'C', 119.0)
# (1186, 'dmabuf_importer_helper', 'C', None)
# (1187, 'flutter-desktop-embedding', 'C++', '7.1k')
# (1188, 'Accessibility-Test-Framework-for-Android', 'Java', 498.0)
# (1189, 'devx-tools', 'Go', 73.0)
# (1190, 'php-crc32', 'PHP', 186.0)
# (1191, 'step197-2020', 'Java', 4.0)
# (1192, 'adb-sync', 'Python', '1.1k')
# (1193, 'mint-line-follower', 'Python', 3.0)
# (1194, 'gps-babel-tower', 'Python', 8.0)
# (1195, 'simhospital', 'Go', 717.0)
# (1196, 'adiantum', 'C', 477.0)
# (1197, 'visionai', 'Python', 47.0)
# (1198, 'xsecurelock', 'C', 914.0)
# (1199, 'cel-policy-templates-go', 'Go', 73.0)
# (1200, 'mawfs', 'Go', 63.0)
# (1201, 'distla_core', 'Python', 3.0)
# (1202, 'abstracttext', 'JavaScript', 78.0)
# (1203, 'mobly-snippet-lib', None, 42.0)
# (1204, 'skywater-pdk-libs-sky130_fd_pr', None, 28.0)
# (1205, 'spdm-accelerator-requirement', None, 2.0)
# (1206, 'longbet', 'C++', 24.0)
# (1207, 'dexmod', 'Python', 63.0)
# (1208, 'space', 'Python', 155.0)
# (1209, 'netbsd-gce', 'Shell', 41.0)
# (1210, 'neural-tangents', 'Jupyter Notebook', '2.4k')
# (1211, 'redgrep', 'C++', 162.0)
# (1212, 'binja-hexagon', 'Python', 116.0)
# (1213, 'hark', None, 9.0)
# (1214, 'mobly-windows', 'Python', 4.0)
# (1215, 'tree-sitter-fidl', 'C', 4.0)
# (1216, 'bazel_rules_install', 'Starlark', 43.0)
# (1217, 'putting-dune', 'Python', 10.0)
# (1218, 'hierarchical-state-machine.dart', 'Dart', 36.0)
# (1219, 'casa-android', 'Kotlin', 270.0)
# (1220, 'security-crawl-maze', 'HTML', 163.0)
# (1221, 'cordova-plugin-browsertab', 'Java', 117.0)
# (1222, 'csv2pprof', 'Go', 2.0)
# (1223, 'compact_enc_det', 'C', 239.0)
# (1224, 'grafika', 'Java', '6.1k')
# (1225, 'gwtmockito', 'Java', 160.0)
# (1226, 'navi', 'Jupyter Notebook', 59.0)
# (1227, 'eidos-audition', 'C++', 33.0)
# (1228, 'alligator2', 'Python', 42.0)
# (1229, 'process-tree', 'C++', 3.0)
# (1230, 'hashtable-benchmarks', 'Jupyter Notebook', 111.0)
# (1231, 'json5format', 'Rust', 111.0)
# (1232, 'gemmlowp', 'C++', '1.8k')
# (1233, 'play-licensing', 'Java', 118.0)
# (1234, 'net_http', 'C++', 25.0)
# (1235, 'objax', 'Python', 775.0)
# (1236, 'safeopen', 'Go', 105.0)
# (1237, 'todo-tracks', 'Go', 185.0)
# (1238, 'alertmanager-irc-relay', 'Go', 58.0)
# (1239, 'crossmodal-3600', 'HTML', 9.0)
# (1240, 'piex', 'C++', 52.0)
# (1241, 'pkcs11test', 'C++', 81.0)
# (1242, 'ceviche-challenges', 'Python', 113.0)
# (1243, 'flutter.plugins', 'Dart', 117.0)
# (1244, 'DOM-Tutorials', 'HTML', 16.0)
# (1245, 'memutil', 'Python', 3.0)
# (1246, 'dsg', 'HTML', 2.0)
# (1247, 'zoekt', None, '1.7k')
# (1248, 'android-lint-performance-probe', 'Java', 157.0)
# ...
# (2406, 'sparrowhawk', 'Shell', 212.0)
# (2407, 'zooshi', 'C++', 291.0)
# (2408, 'http_prefetching', 'JavaScript', 8.0)
# (2409, 'kv-s3105c', 'C', 6.0)
# (2410, 'fastboot-mobile', 'Kotlin', 81.0)
# (2411, 'amss', 'R', 50.0)
# (2412, 'search-samples', 'Java', 549.0)
# (2413, 'abstreet', 'Rust', 36.0)
# (2414, 'dl_bounds', 'Python', 17.0)
# (2415, 'chrome-tabber', 'JavaScript', 14.0)
# (2416, 'beacon-platform', None, 391.0)
# (2417, 'dcm_bulk_onboarding', 'JavaScript', 7.0)
# (2418, 'fast-simple-lcsk', 'C++', 21.0)
# (2419, 'dcm-video-uploader', 'Python', 9.0)
# (2420, 'TouchTime', 'Java', 39.0)
# (2421, 'uniflow-polymer', 'HTML', 165.0)
# (2422, 'rally', 'Java', 38.0)
# (2423, 'teknowledge', 'Python', 30.0)
# (2424, 'clerk', 'C++', 38.0)
# (2425, 'ahdlc', 'C', 14.0)
# (2426, 'aperture_supervision', 'Python', 33.0)
# (2427, 'YetAnotherChatApp', 'Java', 9.0)
# (2428, 'grittibanzli', 'C++', 27.0)
# (2429, 'ds-trix-addon', 'JavaScript', 16.0)
# (2430, 'hat-backup', 'Rust', 252.0)
# (2431, 'angular-sticky-element', 'TypeScript', 22.0)
# (2432, 'vae-seq', 'Python', 177.0)
# (2433, 'cloud-cup', 'JavaScript', 23.0)
# (2434, 'cloud-cup-android', 'Java', 51.0)
# (2435, 'fest', None, 10.0)
# (2436, 'decoupled_gaussian_process', 'Python', 24.0)
# (2437, 'safevarargs', None, 7.0)
# (2438, 'opentest', None, 3.0)
# (2439, 'encrypted-bigquery-client', 'Python', 175.0)
# (2440, 'rbe-integration-test', 'Python', 6.0)
# (2441, 'chained-promise', 'TypeScript', 53.0)
# (2442, 'synergyfinderengineered', 'R', 8.0)
# (2443, 'amp-client-id-library', 'JavaScript', 11.0)
# (2444, 'go-trace', 'Go', 31.0)
# (2445, 'hell0world-curriculum', 'HTML', 7.0)
# (2446, 'intelligent_annotation_dialogs', 'Jupyter Notebook', 29.0)
# (2447, 'cornerstoneMath', 'JavaScript', 7.0)
# (2448, 'burst-denoising', 'Python', 247.0)
# (2449, 'generativemloncloud', 'Python', 58.0)
# (2450, 'aiyprojects-deeplearn-tensorflow', 'TypeScript', 39.0)
# (2451, 'tensorflow-tools', 'JavaScript', 17.0)
# (2452, 'hugeml', None, 6.0)
# (2453, 'coq-bpf', 'Coq', 19.0)
# (2454, 'pinotify', 'Java', 6.0)
# (2455, 'CallBuilder', 'Java', 105.0)
# (2456, 'catnip', 'Python', 26.0)
# (2457, 'yaricv32', 'Verilog', 11.0)
# (2458, 'unigem-objective-c', 'Objective-C', 25.0)
# (2459, 'speech_style_transfer', 'HTML', 4.0)
# (2460, 'perf_api.dart', 'Dart', 9.0)
# (2461, 'golden', 'Go', 54.0)
# (2462, 'latency-benchmark', 'C', 446.0)
# (2463, 'joint_vae', 'OpenEdge ABL', 36.0)
# (2464, 'stumblybot', 'Python', 25.0)
# (2465, 'mt', 'C++', 52.0)
# (2466, 'cornerstoneWebImageLoader', 'JavaScript', 5.0)
# (2467, 'streamy-dart', 'Dart', 61.0)
# (2468, 'dicomParser', 'JavaScript', 7.0)
# (2469, 'vulkan-cpp-library', 'C++', 250.0)
# (2470, 'bbcpu', 'Verilog', 16.0)
# (2471, 'dev-on-chromeos-gce-setup', 'Shell', 7.0)
# (2472, 'pbvi', 'Python', 8.0)
# (2473, 'capture-thread', 'C++', 100.0)
# (2474, 'pblog', 'C', 29.0)
# (2475, 'text2text', 'Python', 55.0)
# (2476, 'ce-open-data-set', None, 8.0)
# (2477, 'voice-iot-maker-demo', 'JavaScript', 69.0)
# (2478, 'terminal-app-function-keys', 'Python', 89.0)
# (2479, 'FakeMaker', 'JavaScript', 22.0)
# (2480, 'genomics-protos', 'Python', 13.0)
# (2481, 'clicktrackers-panel', 'Python', 7.0)
# (2482, 'yara-procdump-python', 'C', 11.0)
# (2483, 'streaming_hdp', 'Go', 4.0)
# (2484, 'coursebuilder-android-container-module', 'Python', 23.0)
# (2485, 'sync3k-server', 'Scala', 21.0)
# (2486, 'tern-closure', 'JavaScript', 33.0)
# (2487, 'helm-broker', 'Go', 33.0)
# (2488, 'ndash', 'C++', 40.0)
# (2489, 'VRD', 'Python', 6.0)
# (2490, 'sync3k-client', 'TypeScript', 19.0)
# (2491, 'acme', 'Go', 382.0)
# (2492, 'dart-sync-webdriver', 'Dart', 22.0)
# (2493, 'dart-sync-socket', 'Dart', 25.0)
# (2494, 'Legilimency', 'Python', 114.0)
# (2495, 'mipsqa', 'Python', 26.0)
# (2496, 'devicehub', 'Java', 11.0)
# (2497, 'gtd-txt', 'Shell', 21.0)
# (2498, 'bitutils', 'Python', 16.0)
# (2499, 'sonic-midi', 'Ruby', 17.0)
# (2500, 'gumbel_sinkhorn', 'Python', 76.0)
# (2501, 'arc-xcode-test-engine', 'PHP', 35.0)
# (2502, 'energystrategies', 'TypeScript', 15.0)
# (2503, 'marmot', 'Go', 189.0)
# (2504, 'clojure-turtle', 'Clojure', 428.0)
# (2505, 'dev-on-chromeos-che', None, 5.0)
# (2506, 'dev-on-chromeos-openvpn', 'Shell', 12.0)
# (2507, 'keytransparency-java', 'Java', 6.0)
# (2508, 'bocado', 'Python', 9.0)
# (2509, 'anvil-build', 'Python', 58.0)
# (2510, 'river', None, 4.0)
# (2511, 'trix-auto-complete', 'JavaScript', 17.0)
# (2512, 'MAB', 'R', 38.0)
# (2513, 'idris-protobuf', 'Idris', 32.0)
# (2514, 'energysimulation', 'Jupyter Notebook', 72.0)
# (2515, 'pyrios', 'Go', 61.0)
# (2516, 'thread-weaver', 'Java', 309.0)
# (2517, 'cwd_jmp', 'Shell', 8.0)
# (2518, 'kratu', 'JavaScript', 283.0)
# (2519, 'codeu_coding_assessment_b_2017', 'Java', 9.0)
# (2520, 'coverage', 'Emacs Lisp', 28.0)
# (2521, 'ts-gulp', None, 2.0)
# (2522, 'git-annex-external-gcs', None, 4.0)
# (2523, 'makerspace-emonth', 'KiCad Layout', 8.0)
# (2524, 'paper-gui', 'HTML', 51.0)
# (2525, 'testrunner-rosemary', 'Java', 3.0)
# (2526, 'spline', 'Java', 28.0)
# (2527, 'creatism', 'HTML', 29.0)
# (2528, 'mockable_filesystem.dart', 'Dart', 12.0)
# (2529, 'okay', 'Go', 22.0)
# (2530, 'metaserver', 'Go', 10.0)
# (2531, 'microdhcpd', 'Go', 15.0)
# (2532, 'pubkeystore', 'Go', 23.0)
# (2533, 'unimorph', 'HTML', 20.0)
# (2534, 'GL-Shader-Validator', 'Python', 40.0)
# (2535, 'light-my-piano', 'Python', 89.0)
# (2536, 'grr_go_client', 'Go', 5.0)
# (2537, 'fury', 'Go', 35.0)
# (2538, 'grr_go_api_client', 'Go', 5.0)
# (2539, 'rttcp', 'Python', 33.0)
# (2540, 'functions-demo', 'JavaScript', 6.0)
# (2541, 'packet-queue', 'Python', 31.0)
# (2542, 'easybundler', 'Java', 54.0)
# (2543, 'chkstream', 'Python', 18.0)
# (2544, 'glmmplus', 'R', 12.0)
# (2545, 'codeu_coding_assessment_2017', 'Java', 10.0)
# (2546, 'address-geocoder-js', 'HTML', 11.0)
# (2547, 'classp', 'Bison', 169.0)
# (2548, 'xmpmeta', 'C++', 19.0)
# (2549, 'depth_fusion', 'C++', 18.0)
# (2550, 'amp-pwa-demo', 'JavaScript', 113.0)
# (2551, 'Zhi', 'Python', 28.0)
# (2552, 'agata', 'JavaScript', 14.0)
# (2553, 'prerender-test', 'JavaScript', 15.0)
# (2554, 'audit-normalmap', 'C', 15.0)
# (2555, 'varstruct', 'C++', 18.0)
# (2556, 'emre', 'C++', 13.0)
# (2557, 'simple-reinforcement-learning', 'Python', 58.0)
# (2558, 'homebrew-google-authenticator', 'Ruby', 29.0)
# (2559, 'request-test', 'Python', 6.0)
# (2560, 'blockly-repo', None, 10.0)
# (2561, 'pindrop', 'C++', 142.0)
# (2562, 'goldfinch', None, 64.0)
# (2563, 'scene_lab', 'C++', 57.0)
# (2564, 'corgi', 'C++', 251.0)
# (2565, 'dropzone-polyfill', 'HTML', 5.0)
# (2566, 'ot-crdt-papers', 'JavaScript', 249.0)
# (2567, 'windowtester', 'Java', 19.0)
# (2568, 'fpc', 'C', 29.0)
# (2569, 'fchan-go', 'Go', 311.0)
# (2570, 'xdelta3-decoder-js', 'C', 13.0)
# (2571, 'appengine-phabricator', 'Shell', 19.0)
# (2572, 'cpp-frp', 'C++', 69.0)
# (2573, 'yang_vocoder', 'MATLAB', 91.0)
# (2574, 'keystone', 'Elm', 31.0)
# (2575, 'adapt-googleanalytics', 'JavaScript', 8.0)
# (2576, 'deepboost', 'C++', 154.0)
# (2577, 'mcic-coco', None, 24.0)
# (2578, 'readahead', 'Go', 136.0)
# (2579, 'source_transformer.dart', 'Dart', 9.0)
# (2580, 'mcafp', 'Python', 38.0)
# (2581, 'gtm-oauth', 'Objective-C', 24.0)
# (2582, 'morphie', 'C++', 23.0)
# (2583, 'libgep', 'C++', 55.0)
# (2584, 'smilesparser', 'Python', 13.0)
# (2585, 'built_json.dart', None, 19.0)
# (2586, 'conferenceDB', 'HTML', 9.0)
# (2587, 'indexable-pwa-samples', 'JavaScript', 56.0)
# (2588, 'enum_class.dart', None, 15.0)
# (2589, 'sass_generator', None, 4.0)
# (2590, 'vpn-reverse-tether', 'C', 190.0)
# (2591, 'protocall', 'Python', 13.0)
# (2592, 'transliteration', None, 56.0)
# (2593, 'power-traces', 'Protocol Buffer', 8.0)
# (2594, 'indexed-db-as-promised', 'JavaScript', 26.0)
# (2595, 'gotrace', None, 21.0)
# (2596, 'cameraraw', 'Go', 26.0)
# (2597, 'everythingisconnected', 'JavaScript', 19.0)
# (2598, 'libkml', 'C++', 97.0)
# (2599, 'geovelo', 'JavaScript', 44.0)
# (2600, 'gfw-toolkit', 'Python', 29.0)
# (2601, 'googleapps-message-recall', 'Python', 16.0)
# (2602, 'macops-MOMenu', 'Objective-C', 47.0)
# (2603, 'dart2java', 'Java', 61.0)
# (2604, 'param_runner', 'Shell', 4.0)
# (2605, 'gde-speakersbureau', 'JavaScript', 7.0)
# (2606, 'AppUpdateTrackerLib', 'Java', 7.0)
# (2607, 'rustcxx', 'Rust', 509.0)
# (2608, 'dualhttp', 'JavaScript', 22.0)
# (2609, 'go-webdav', 'Go', 70.0)
# (2610, 'dorusu-js', 'JavaScript', 40.0)
# (2611, 'identity-toolkit-go-client', 'Go', 57.0)
# (2612, 'dynamex-proto', 'Protocol Buffer', 7.0)
# (2613, 'auto-common', None, 5.0)
# (2614, 'auto-service', None, 5.0)
# (2615, 'auto-factory', None, 5.0)
# (2616, 'prudaq', 'Eagle', 123.0)
# (2617, 'realtime-help', 'Python', 20.0)
# (2618, 'pepper.js', 'JavaScript', 324.0)
# (2619, 'instant-hangouts', 'JavaScript', 184.0)
# (2620, 'LiquidFunPaint', 'Java', 166.0)
# (2621, 'easy-gwt-mock', 'Java', 13.0)
# (2622, 'gofountain', 'Go', 110.0)
# (2623, 'VoltAir', 'C++', 317.0)
# (2624, 'bzip2-rpc', 'C', 14.0)
# (2625, 'gipfeli', 'C++', 117.0)
# (2626, 'go-circuits', 'Go', 15.0)
# (2627, 'rpki-mgmt', 'Puppet', 6.0)
# (2628, 'simplecfg', 'Java', 11.0)
# (2629, 'maketrace', 'C++', 19.0)
# (2630, 'Chrome.Docs', 'JavaScript', 27.0)
# (2631, 'bluesky-watchface', 'C', 11.0)
# (2632, 'slowfs', 'Go', 58.0)
# (2633, 'arc-jazzy-linter', 'PHP', 18.0)
# (2634, 'merge_pyi', 'Python', 15.0)
# (2635, 'drone-firebase', 'Go', 14.0)
# (2636, 'cncmicroscope-cad', 'OpenSCAD', 15.0)
# (2637, 'access-bridge-explorer', 'C#', 126.0)
# (2638, 'gitwf', None, 4.0)
# (2639, 'arc-proselint', 'PHP', 17.0)
# (2640, 'channel-id-enclave', None, 33.0)
# (2641, 'generator-goro', 'JavaScript', 24.0)
# (2642, 'xpaf', 'C++', 153.0)
# (2643, 'google-empty-test-module', None, 3.0)
# (2644, 'cloud-reporting', 'Java', 8.0)
# (2645, 'reagera', 'Java', 13.0)
# (2646, 'py-decorators-tutorial', 'Jupyter Notebook', 31.0)
# (2647, 'identity-toolkit-node-client', 'JavaScript', 30.0)
# (2648, 'GOS-conventions', 'Shell', 8.0)
# (2649, 'identity-toolkit-java-client', 'Java', 37.0)
# (2650, 'jalic', 'C', 11.0)
# (2651, 'arc-regex-line-length-linter', 'PHP', 8.0)
# (2652, 'identity-toolkit-ruby-client', 'Ruby', 10.0)
# (2653, 'file-system-stress-testing', 'C', 104.0)
# (2654, 'linux-sensor', 'C', 32.0)
# (2655, 'multibox', None, 307.0)
# (2656, 'offline-content-packager', None, 35.0)
# (2657, 'crush-tools', 'Shell', 150.0)
# (2658, 'flutter-data', 'Dart', 11.0)
# (2659, 'resolver-library', 'Python', 7.0)
# (2660, 'hops', 'C++', 11.0)
# (2661, 'kythe-cloud9', 'JavaScript', 7.0)
# (2662, 'physical-web-core', None, 3.0)
# (2663, 'flooefi', None, 10.0)
# (2664, 'serialization.dart', 'Dart', 32.0)
# (2665, 'templatekit', 'Objective-C', 19.0)
# (2666, 'metrosvg', 'C++', 13.0)
# (2667, 'paramgmt', 'Python', 85.0)
# (2668, 'pienoon', 'C++', 438.0)
# (2669, 'translation-cards', 'Java', 17.0)
# (2670, 'topdown-btg-preordering', 'C++', 16.0)
# (2671, 'openpgp-interop', None, 8.0)
# (2672, 'appengine-codiad', 'JavaScript', 39.0)
# (2673, 'godata', 'Go', 26.0)
# (2674, 'opentest4j', 'Java', 5.0)
# (2675, 'identity-toolkit-php-client', 'PHP', 37.0)
# (2676, 'google-maven-parents', None, 6.0)
# (2677, 'identity-toolkit-python-client', 'Python', 32.0)
# (2678, 'Refaster', 'Java', 54.0)
# (2679, 'strabo', 'Elixir', 60.0)
# (2680, 'http2preload', 'Go', 20.0)
# (2681, 'checkers_classic', 'Python', 7.0)
# (2682, 'node-nest', 'JavaScript', 4.0)
# (2683, 'intellij-cmdline-vcs-plugin', 'Java', 4.0)
# (2684, 'docopt-scripts', 'Go', 6.0)
# (2685, 'xpra-upstart', None, 3.0)
# (2686, 'steamkeysactivator', 'AppleScript', 29.0)
# (2687, 'homebrew-xpra', 'Ruby', 9.0)
# (2688, 'shipshape-demo', 'Python', 4.0)
# (2689, 'hashing-demo', 'C++', 29.0)
# (2690, 'autopiper', 'C++', 48.0)
# (2691, 'inception', None, 877.0)
# (2692, 'clang-lens', 'Haskell', 20.0)
# (2693, 'crisis-info-hub', 'JavaScript', 35.0)
# (2694, 'dart-immutables', 'Dart', 6.0)
# (2695, 'streamhtmlparser', 'C', 17.0)
# (2696, 'pods-helper', 'Objective-C', 5.0)
# (2697, 'cluster-insight', 'Python', 99.0)
# (2698, 'freebase-wikidata-converter', 'PHP', 63.0)
# (2699, 'snappy-start', 'C', 450.0)
# (2700, 'capsicum-man-pages', 'Groff', 10.0)
# (2701, 'rust-multihash', 'Rust', 62.0)
# (2702, 'organ-donor-app', None, 3.0)
# (2703, 'trace-viewer', None, 491.0)
# (2704, 'rowhammer-test', 'C++', 984.0)
# (2705, 'ferret', 'Java', 8.0)
# (2706, 'module-server', 'JavaScript', 565.0)
# (2707, 'autoparse', 'Ruby', 146.0)
# (2708, 'android-studio-check', 'Java', 14.0)
# (2709, 'chromeos-filesystems', 'JavaScript', 125.0)
# (2710, 'gojiraw', 'Go', 16.0)
# (2711, 'terminal-py', 'Python', 7.0)
# (2712, 'lmctfy', 'C++', '3.4k')
# (2713, 'dart-shapeshift', 'Dart', 13.0)
# (2714, 'calenviroscreen', 'R', 8.0)
# (2715, 'cncmicroscope-code', 'C++', 24.0)
# (2716, 'o3dtoydefense', 'JavaScript', 8.0)
# (2717, 'epr', 'JavaScript', 16.0)
# (2718, 'codename-mvsv', 'JavaScript', 9.0)
# (2719, 'io-captions-gadget', 'Python', 5.0)
# (2720, 'ytstatistics-demo', 'Java', 5.0)
# (2721, 'sensei', 'C++', 55.0)
# (2722, 'comid', 'Dart', 15.0)
# (2723, 'service_worker.dart', 'Dart', 9.0)
# (2724, 'google-visualization-issues', None, 286.0)
# (2725, 'dart-doc_coverage', 'Dart', 7.0)
# (2726, 'voter-info-tool', 'JavaScript', 7.0)
# (2727, 'chrome-language-immersion', 'JavaScript', 46.0)
# (2728, 'coursebuilder_xblock_module', 'Python', 17.0)
# (2729, 'py-html-contextual-escaping', 'Python', 4.0)
# (2730, 'json-sans-eval', 'HTML', 7.0)
# (2731, 'mysql-tools', 'Python', 212.0)
# (2732, 'refr', 'C++', 28.0)
# (2733, 'coursebuilder-hello-world-module', 'Python', 8.0)
# (2734, 'dart-emacs-plugin-unsupported', 'Emacs Lisp', 12.0)
# (2735, 'older-mirrored-patches', None, 4.0)
# (2736, 'objectfilter', 'Python', 4.0)
# (2737, 'retrofit', 'Java', 43.0)
# (2738, 'nfc-smart-tag', 'Java', 12.0)
# (2739, 'irrduino', 'Processing', 51.0)
# (2740, 'reportlatency', 'Perl', 6.0)
# (2741, 'gmailsnooze', 'JavaScript', 16.0)
# (2742, 'deliberate', None, 4.0)
# (2743, 'network-visualizer-x', None, 5.0)
# (2744, 'reboot-somalia', None, 3.0)
# (2745, 'citizen-x', None, 5.0)
# (2746, 'pytypedecl', 'Python', 66.0)
# (2747, 'rysim', 'Erlang', 7.0)
# (2748, 'jsontoken-tmp', None, 3.0)
# (2749, 'go-shlex', None, 5.0)
# (2750, 'zarathustra', 'Java', 14.0)
# (2751, 'pull-request-mailer', 'Haskell', 45.0)
# (2752, 'elfling', 'C++', 25.0)
# (2753, 'vim-ft-vroom', 'Vim Script', 12.0)
# (2754, 'picview-for-android', 'Java', 51.0)
# (2755, 'picasa-app-demo', 'Java', 10.0)
# (2756, 'web-starter-kit-extras', None, 71.0)
# (2757, 'simple-pedometer', 'Java', 77.0)
# (2758, 'sensor-data-collection-library', 'Java', 46.0)
# (2759, 'ashier', 'Python', 29.0)
# (2760, 'coursebuilder-lti-module', 'Python', 16.0)
# (2761, 'episodes.dart', 'Dart', 14.0)
# (2762, 'polymer-dart-log-controller', 'Dart', 8.0)
# (2763, 'ebola-tools', 'Python', 15.0)
# (2764, 'pubsubhubbub', None, 6.0)
# (2765, 'dart-tagtree', 'Dart', 78.0)
# (2766, 'turing-doodle', 'JavaScript', 170.0)
# (2767, 'linear-book-scanner', 'Python', 81.0)
# (2768, 'java-thread-sanitizer', 'Java', 76.0)
# (2769, 'gin', None, 5.0)
# (2770, 'go-glicko2', None, 5.0)
# (2771, 'rct-automation', 'C++', 23.0)
# (2772, 'Idris-dev', 'Haskell', 9.0)
# (2773, 'forcefield', 'Gosu', 48.0)
# (2774, 'dart-gif-encoder', 'Dart', 28.0)
# (2775, 'glassbox', 'R', 22.0)
# (2776, 'coursebuilder-learning-analytics', None, 5.0)
# (2777, 'NLSdata', 'R', 8.0)
# (2778, 'jenkins-flaky-test-report', None, 5.0)
# (2779, 'build-debian-cloud', 'Python', 35.0)
# (2780, 'dart-collab', 'Dart', 47.0)
# (2781, 'wheelbarrow', 'Python', 11.0)
# (2782, 'photo-sphere', None, 4.0)
# (2783, 'oss-bench', None, 6.0)
# (2784, 'heartbleed-burp-extension', 'Java', 13.0)
# (2785, 'lab_device_proxy', 'Python', 39.0)
# (2786, 'gdal-autotest2', None, 4.0)
# (2787, 'patchfield', 'Java', 277.0)
# (2788, 'googleapps-password-generator', None, 27.0)
# (2789, 'YouCompleteSubl', None, 2.0)
# (2790, 'favcolor-findidp', None, 5.0)
# (2791, 'appengine_xblock_runtime', 'Python', 19.0)
# (2792, 'memcache-collections', 'Python', 66.0)
# (2793, 'course-builder', None, 5.0)
# (2794, 'favcolor-android', 'Java', 40.0)
# (2795, 'systemjs', 'JavaScript', 64.0)
# (2796, 'favcolor-ios', None, 5.0)
# (2797, 'pixelcycle-sample-app', 'Dart', 10.0)
# (2798, 'container-rfc', None, 11.0)
# (2799, 'gae-channel-api.dart', 'Dart', 10.0)
# (2800, 'ChannelPlate', 'JavaScript', 23.0)
# (2801, 'testRunner', 'JavaScript', 10.0)
# (2802, 'devtoolsExtended', 'JavaScript', 73.0)
# (2803, 'self-hosted-rss-to-email', 'Go', 29.0)
# (2804, 'zimu', 'C', 6.0)
# (2805, 'tsviewdb', 'JavaScript', 125.0)
# (2806, 'beta-binomial-fitting', None, 6.0)
# (2807, 'wiberg-minimization', None, 17.0)
# (2808, 'crx2app', 'JavaScript', 22.0)
# (2809, 'concatenate.js', 'JavaScript', 92.0)
# (2810, 'firmata.py', 'Python', 21.0)
# (2811, 'sirius', None, 8.0)
